# %%
import ipynb.fs.defs.functions_new as fct
import pandas as pd
import numpy as np
import pickle

# %%
# Load IDs
with open('uniqueIDs.pkl', 'rb') as f:
    uniqueIDs = pickle.load(f)

# %% [markdown]
# ## Model 0 - alpha

# %%
# Model specification
mod_info = {}
mod_info['name'] = 'model0_alpha'
mod_info['value_fct'] = fct.rescorla_wagner_1t
mod_info['dec_fct'] = fct.my_softmax_1t
mod_info['param_names'] = ['alpha']

# For fitting
param_lower_bounds = [0]
param_upper_bounds = [1]

# Save
all_users_folder = 'data/all_users/fit/' + mod_info['name'] + '/'
file_name = all_users_folder + 'mod_parameters.pkl'
with open(file_name, 'wb') as f:
    pickle.dump(mod_info, f)

# fit to all users
fct.fit_model_to_data(uniqueIDs, mod_info, param_lower_bounds, param_upper_bounds, all_users_folder)

# %% [markdown]
# ## Model 0 - v0

# %%
# Model specification
mod_info = {}
mod_info['name'] = 'model0_v0'
mod_info['value_fct'] = fct.rescorla_wagner_1t
mod_info['dec_fct'] = fct.my_softmax_1t
mod_info['param_names'] = ['v0']

# For fitting
param_lower_bounds = [-5]
param_upper_bounds = [ 5]

# Save
all_users_folder = 'data/all_users/fit/' + mod_info['name'] + '/'
file_name = all_users_folder + 'mod_parameters.pkl'
with open(file_name, 'wb') as f:
    pickle.dump(mod_info, f)

# fit to all users
fct.fit_model_to_data(uniqueIDs, mod_info, param_lower_bounds, param_upper_bounds, all_users_folder)

# %% [markdown]
# ## Model 0 - beta

# %%
# Model specification
mod_info = {}
mod_info['name'] = 'model0_beta'
mod_info['value_fct'] = fct.rescorla_wagner_1t
mod_info['dec_fct'] = fct.my_softmax_1t
mod_info['param_names'] = ['beta']

# For fitting
param_lower_bounds = [0.01]
param_upper_bounds = [   5]

# Save
all_users_folder = 'data/all_users/fit/' + mod_info['name'] + '/'
file_name = all_users_folder + 'mod_parameters.pkl'
with open(file_name, 'wb') as f:
    pickle.dump(mod_info, f)

# fit to all users
fct.fit_model_to_data(uniqueIDs, mod_info, param_lower_bounds, param_upper_bounds, all_users_folder)

# %% [markdown]
# ## Model 0 - alpha, beta

# %%
# Model specification
mod_info = {}
mod_info['name'] = 'model0_alpha_beta'
mod_info['value_fct'] = fct.rescorla_wagner_1t
mod_info['dec_fct'] = fct.my_softmax_1t
mod_info['param_names'] = ['alpha', 'beta']

# For fitting
param_lower_bounds = [0, 0.01]
param_upper_bounds = [1,    3]

# Save
all_users_folder = 'data/all_users/fit/' + mod_info['name'] + '/'
file_name = all_users_folder + 'mod_parameters.pkl'
with open(file_name, 'wb') as f:
    pickle.dump(mod_info, f)

# fit to all users
fct.fit_model_to_data(uniqueIDs, mod_info, param_lower_bounds, param_upper_bounds, all_users_folder)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [13], in <cell line: 19>()
#      16     pickle.dump(mod_info, f)
#      18 # fit to all users
# ---> 19 fct.fit_model_to_data(uniqueIDs, mod_info, param_lower_bounds, param_upper_bounds, all_users_folder)
#
# File /Volumes/GoogleDrive/Mon Drive/PAT/data_analysis/functions_new.ipynb:385, in fit_model_to_data(uniqueIDs, mod_info, param_lower_bounds, param_upper_bounds, all_users_folder)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 85,
#       6    "id": "a61108ed-fb3a-4c22-b0d5-c7046ffa1c71",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "import numpy as np\n",
#      11     "import pandas as pd\n",
#      12     "import pickle\n",
#      13     "import random\n",
#      14     "from scipy.optimize import minimize\n",
#      15     "from scipy.stats import pearsonr, bernoulli\n",
#      16     "import matplotlib.pyplot as plt\n",
#      17     "import seaborn as sns\n",
#      18     "import math\n",
#      19     "import ptitprince as pt # rainplot"
#      20    ]
#      21   },
#      22   {
#      23    "cell_type": "markdown",
#      24    "id": "c1521503-0078-4f97-8797-934f1f052c4f",
#      25    "metadata": {},
#      26    "source": [
#      27     "## Plot"
#      28    ]
#      29   },
#      30   {
#      31    "cell_type": "code",
#      32    "execution_count": 88,
#      33    "id": "25470086-7631-4ff6-9d93-01d68ce4af64",
#      34    "metadata": {},
#      35    "outputs": [],
#      36    "source": [
#      37     "def fig_modelpred_on_behav(ev_per_trial, p_hit_per_trial, all_users_folder):\n",
#      38     "\n",
#      39     "    # Timepoints\n",
#      40     "    window_size = 16\n",
#      41     "    N_trials = 112\n",
#      42     "    timepoints = ['t'+ str(t+1) for t in range(int(N_trials/window_size))]\n",
#      43     "\n",
#      44     "    # Load behaviour and compute stats\n",
#      45     "    hit_perc_per_t = pd.read_pickle(all_users_folder + 'hit_perc_per_t/hit_perc_per_t_w' + str(window_size) + '.pkl');\n",
#      46     "    hit_perc_per_t.drop('ID', axis=1, inplace=True);\n",
#      47     "    stats_hits_perc_per_t = hit_perc_per_t.groupby('Code').agg(['mean', 'var']).T.swaplevel(axis=0);\n",
#      48     "\n",
#      49     "    # Load model predictions and compute stats\n",
#      50     "    ev_per_trial.drop('ID', axis=1, inplace=True);\n",
#      51     "    stats_ev_per_trial = ev_per_trial.groupby('Cue').agg(['mean', 'var']).T.swaplevel(axis=0)\n",
#      52     "    stats_ev_per_trial.columns = 'Cue_'+stats_ev_per_trial.columns\n",
#      53     "\n",
#      54     "    p_hit_per_trial.drop('ID', axis=1, inplace=True);\n",
#      55     "    stats_p_hit_per_trial = p_hit_per_trial.groupby('Cue').agg(['mean', 'var']).T.swaplevel(axis=0)\n",
#      56     "    stats_p_hit_per_trial.columns = 'Cue_'+stats_p_hit_per_trial.columns\n",
#      57     "\n",
#      58     "    # Plot\n",
#      59     "    f, axs = plt.subplots(2, 1, figsize=(10, 6), dpi=80)\n",
#      60     "    plt.subplots_adjust(hspace = 0.4)\n",
#      61     "\n",
#      62     "    x_mod = np.arange(len(stats_ev_per_trial.loc['mean']))+1\n",
#      63     "    x_behav = np.arange(len(timepoints))*4+4\n",
#      64     "\n",
#      65     "    for cue, color, alpha in zip(['Cue_HP', 'Cue_LP', 'Cue_LR', 'Cue_HR'], ['red', 'red', 'green', 'green'], [0.6, 0.3, 0.3, 0.6]):\n",
#      66     "        # Hit probabilites\n",
#      67     "        m=axs[0].plot(x_mod, stats_p_hit_per_trial.loc['mean'][cue], '.-', color=color, alpha=alpha);\n",
#      68     "        # Behaviour: sliding average\n",
#      69     "        b=axs[0].plot(x_behav, stats_hits_perc_per_t.loc['mean'][cue], '.-', color='gray', alpha=alpha);\n",
#      70     "        # Expected values\n",
#      71     "        m=axs[1].plot(x_mod, stats_ev_per_trial.loc['mean'][cue], '.-', color=color, alpha=alpha);\n",
#      72     "\n",
#      73     "    for ax in axs:\n",
#      74     "        ax.grid(axis='x', color='0.95');\n",
#      75     "        ax.set_xticks(x_mod);\n",
#      76     "    \n",
#      77     "    axs[0].set_title('Model probability of hit', fontsize=16);\n",
#      78     "    axs[1].set_title('Model expected values', fontsize=16);\n",
#      79     "    \n",
#      80     "    axs[0].set_ylabel(\"Hit [%]\", fontsize=16);\n",
#      81     "    axs[1].set_ylabel(\"Values\", fontsize=16);\n",
#      82     "    \n",
#      83     "    axs[0].set_ylim([0,1]);\n",
#      84     "    axs[1].set_ylim([-3,3]);\n",
#      85     "    \n",
#      86     "    axs[0].legend(b, {'Behaviour'})\n",
#      87     "    \n",
#      88     "    plt.show()"
#      89    ]
#      90   },
#      91   {
#      92    "cell_type": "code",
#      93    "execution_count": 87,
#      94    "id": "2ebec1bb-c224-4a23-93b3-d2c188f2e43f",
#      95    "metadata": {},
#      96    "outputs": [],
#      97    "source": [
#      98     "def plot_model_parameters(data_mod, param_names):\n",
#      99     "    \n",
#     100     "    Nparam = len(param_names)\n",
#     101     "    \n",
#     102     "    if Nparam<=3:\n",
#     103     "        f, axs = plt.subplots(1, Nparam, figsize=(Nparam*6, 5))\n",
#     104     "    elif Nparam==4:\n",
#     105     "        f, axs = plt.subplots(2, 2, figsize=(2*6, 2*5))\n",
#     106     "        axs = axs.reshape(-1)\n",
#     107     "    else:\n",
#     108     "        f, axs = plt.subplots(2, 3, figsize=(3*6, 2*5))\n",
#     109     "        axs = axs.reshape(-1)\n",
#     110     "        \n",
#     111     "    plt.subplots_adjust(hspace = 0.3)\n",
#     112     "        \n",
#     113     "    pal = sns.color_palette(n_colors=1)\n",
#     114     "    \n",
#     115     "    if Nparam == 1:\n",
#     116     "        ax, param = axs, param_names[0]\n",
#     117     "        y = data_mod[param].squeeze().tolist()\n",
#     118     "        pt.half_violinplot(ax=ax, x = y, palette = pal, bw = .2, cut = 0., scale = \"area\", width = .6, inner = None, orient = 'h')\n",
#     119     "        sns.stripplot(ax=ax, x = y, palette = pal, edgecolor = \"white\", size = 5, jitter = 1, zorder = 0, orient = 'h', alpha=.35)\n",
#     120     "        sns.boxplot(x = y, saturation=1, showfliers=False, width=0.15, boxprops={'zorder': 3, 'facecolor': 'none'}, ax=ax)\n",
#     121     "        ax.set_title('Parameter: ' + param, fontsize=18)\n",
#     122     "        ax.set_xlabel('Best fit parameter value', fontsize=16)\n",
#     123     "\n",
#     124     "    else:\n",
#     125     "        for ax, param in zip(axs, param_names):\n",
#     126     "            y = data_mod[param].tolist()\n",
#     127     "            # plot clouds\n",
#     128     "            pt.half_violinplot(ax=ax, x = y, palette = pal, bw = .2, cut = 0., scale = \"area\", width = .6, inner = None, orient = 'h')\n",
#     129     "            # add rain\n",
#     130     "            sns.stripplot(ax=ax, x = y, palette = pal, edgecolor = \"white\", size = 5, jitter = 1, zorder = 0, orient = 'h', alpha=.35)\n",
#     131     "            sns.boxplot(x = y, saturation=1, showfliers=False, width=0.15, boxprops={'zorder': 3, 'facecolor': 'none'}, ax=ax)\n",
#     132     "            # Makeup\n",
#     133     "            ax.set_title('Parameter: ' + param, fontsize=18)\n",
#     134     "            ax.set_xlabel('Best fit parameter value', fontsize=16)\n",
#     135     "\n",
#     136     "    plt.show()"
#     137    ]
#     138   },
#     139   {
#     140    "cell_type": "code",
#     141    "execution_count": 2,
#     142    "id": "cd22618d-6a43-4053-addc-f66bd19ae031",
#     143    "metadata": {},
#     144    "outputs": [],
#     145    "source": [
#     146     "def plot_correlation(title, x, y, data, ax, text_pos, xlabel, ylabel, xlim, ylim):\n",
#     147     "        \n",
#     148     "    # Initialise figue\n",
#     149     "    ax.set_title(title, fontsize = 22)\n",
#     150     "\n",
#     151     "    # Scatter plot\n",
#     152     "    sns.scatterplot( x = x, y = y, data = data, ax = ax);\n",
#     153     "\n",
#     154     "    # Linear regression line\n",
#     155     "    sns.regplot(x = x, y = y, data = data, ax = ax);\n",
#     156     "    \n",
#     157     "    # Plot horizontal line\n",
#     158     "    ax.axhline(y=0, color='k', linestyle=':')\n",
#     159     "\n",
#     160     "    # Compute correlation stats (r and p values)\n",
#     161     "    r, p = pearsonr(data[x], data[y])\n",
#     162     "    \n",
#     163     "    # Write stats on fig\n",
#     164     "    if p<0.01:\n",
#     165     "        ax.text(text_pos[0], text_pos[1], 'r={:.2f} \\np<0.01'.format(r, p), transform=ax.transAxes, fontsize=16)\n",
#     166     "    else:    \n",
#     167     "        ax.text(text_pos[0], text_pos[1], 'r={:.2f} \\np={:.2g}'.format(r, p), transform=ax.transAxes, fontsize=16)\n",
#     168     "    \n",
#     169     "    # Properties\n",
#     170     "    ax.set_ylabel(ylabel, fontsize=15)\n",
#     171     "    ax.set_ylim(bottom=ylim[0], top=ylim[1])\n",
#     172     "    \n",
#     173     "    ax.set_xlabel(xlabel, fontsize=15)\n",
#     174     "    ax.set_xlim(left=xlim[0], right=xlim[1])"
#     175    ]
#     176   },
#     177   {
#     178    "cell_type": "code",
#     179    "execution_count": 43,
#     180    "id": "752cfc61-37ae-45e9-ba77-dc29f33b1ae3",
#     181    "metadata": {},
#     182    "outputs": [],
#     183    "source": [
#     184     "def plot_param_recov_correlations(df):\n",
#     185     "    \n",
#     186     "    # get Param names\n",
#     187     "    param_names = df.columns[2::].tolist()\n",
#     188     "\n",
#     189     "    Nparam = len(param_names)\n",
#     190     "\n",
#     191     "    if Nparam<=3:\n",
#     192     "        #f, axs = plt.subplots(1, Nparam, figsize=(Nparam*6, 5))\n",
#     193     "        f, axs = plt.subplots(1, Nparam, figsize=(Nparam*4, 3))\n",
#     194     "    elif Nparam==4:\n",
#     195     "        f, axs = plt.subplots(2, 2, figsize=(2*6, 2*5))\n",
#     196     "        axs = axs.reshape(-1)\n",
#     197     "    else:\n",
#     198     "        f, axs = plt.subplots(2, 3, figsize=(3*6, 2*5))\n",
#     199     "        axs = axs.reshape(-1)\n",
#     200     "\n",
#     201     "    plt.subplots_adjust(hspace = 0.3)\n",
#     202     "\n",
#     203     "    for i, param in enumerate(param_names):\n",
#     204     "\n",
#     205     "        lims = [math.floor(df[param].min()), math.ceil(df[param].max())]\n",
#     206     "\n",
#     207     "        df_tmp = df.pivot(index = 'simID', columns = 'Type', values=param)\n",
#     208     "        \n",
#     209     "        ax = axs if Nparam==1 else axs[i]\n",
#     210     "\n",
#     211     "        plot_correlation(title=param, x='Fit', y='Sim',\n",
#     212     "                         data=df_tmp, ax=ax, text_pos=[.2,.8], \n",
#     213     "                         xlabel='Fitted', ylabel='Simulated', xlim=lims, ylim=lims)\n",
#     214     "    plt.show()"
#     215    ]
#     216   },
#     217   {
#     218    "cell_type": "code",
#     219    "execution_count": 44,
#     220    "id": "3cc4a79a-7ffe-422e-b508-9e0ba6a66029",
#     221    "metadata": {},
#     222    "outputs": [],
#     223    "source": [
#     224     "def plot_param_recov_conf_matrix(df):\n",
#     225     "    \n",
#     226     "    #f, axs = plt.subplots(1, 1, figsize=(7, 6))\n",
#     227     "    f, axs = plt.subplots(1, 1, figsize=(4, 3))\n",
#     228     "\n",
#     229     "    # get Param names\n",
#     230     "    param_names = df.columns[2::].tolist()\n",
#     231     "\n",
#     232     "    # Initialise matrices of nans\n",
#     233     "    Nparam = len(param_names)\n",
#     234     "    confusion_mat = np.empty((Nparam, Nparam))\n",
#     235     "    confusion_mat[:] = np.NaN\n",
#     236     "\n",
#     237     "    # Store pearson correlations\n",
#     238     "    for i_sim, param_sim_name in enumerate(param_names):\n",
#     239     "        for i_fit, param_fit_name in enumerate(param_names):\n",
#     240     "            param_sim_values = df[df['Type']=='Sim'][param_sim_name]\n",
#     241     "            param_fit_values = df[df['Type']=='Fit'][param_fit_name]\n",
#     242     "            corr, _ = pearsonr(param_sim_values, param_fit_values)\n",
#     243     "            confusion_mat[i_sim, i_fit] = corr\n",
#     244     "            #print('sim: ' + param_sim_name + ' fit: ' + param_fit_name)\n",
#     245     "            #print(corr)\n",
#     246     "\n",
#     247     "    # Plot confusion matrix\n",
#     248     "    ax = sns.heatmap(confusion_mat.T, vmin=-1, vmax=1, annot=True, annot_kws={\"fontsize\":12, \"weight\":\"normal\"}, cmap='coolwarm')\n",
#     249     "    ax.set_xticklabels(param_names, fontsize = 12)\n",
#     250     "    ax.set_yticklabels(param_names, fontsize = 12)\n",
#     251     "    ax.set_xlabel('Simulated', fontsize = 14)\n",
#     252     "    ax.set_ylabel('Fitted', fontsize = 14)\n",
#     253     "    plt.show()\n",
#     254     "    "
#     255    ]
#     256   },
#     257   {
#     258    "cell_type": "markdown",
#     259    "id": "a346f1ad-120b-44b8-b3ef-cef824c7f423",
#     260    "metadata": {},
#     261    "source": [
#     262     "## Model class"
#     263    ]
#     264   },
#     265   {
#     266    "cell_type": "code",
#     267    "execution_count": 80,
#     268    "id": "d8fca603-74c6-46b0-b3c4-58df9d552d54",
#     269    "metadata": {},
#     270    "outputs": [],
#     271    "source": [
#     272     "class Model:\n",
#     273     "    \n",
#     274     "    def __init__(self, mod_name, value_fct, dec_fct, param_names):\n",
#     275     "        self.mod_name = mod_name\n",
#     276     "        self.value_fct = value_fct\n",
#     277     "        self.dec_fct = dec_fct\n",
#     278     "        self.param_names = param_names\n",
#     279     "        self.param_values = []\n",
#     280     "        self.fbs_all_cues = []\n",
#     281     "        self.p_hit_all_cues = []\n",
#     282     "        self.vt_all_cues = []\n",
#     283     "        self.pe_all_cues = []\n",
#     284     "        self.trialNo_all_cues = []\n",
#     285     "        self.isHit_all_cues = []\n",
#     286     "        self.Ntrials_per_cue = []\n",
#     287     "        self.nLLs_all_cues = []\n",
#     288     "        self.total_nLL_per_cue = []\n",
#     289     "        self.nLL = []\n",
#     290     "        \n",
#     291     "    def __repr__(self):\n",
#     292     "        return f'Model(\"{self.mod_name}\",\"{self.param_names}\")'\n",
#     293     "    \n",
#     294     "    def set_part_data(self, ID, fbs_all_cues, isHit_all_cues, trialNo_all_cues):\n",
#     295     "        self.ID = ID\n",
#     296     "        self.fbs_all_cues = fbs_all_cues\n",
#     297     "        self.isHit_all_cues = isHit_all_cues\n",
#     298     "        self.trialNo_all_cues = trialNo_all_cues\n",
#     299     "        self.p_hit_all_cues = self.get_empty_dict(fbs_all_cues)\n",
#     300     "        self.vt_all_cues = self.get_empty_dict(fbs_all_cues)\n",
#     301     "        self.pe_all_cues = self.get_empty_dict(fbs_all_cues)\n",
#     302     "        self.nLLs_all_cues = self.get_empty_dict(fbs_all_cues)\n",
#     303     "        self.total_nLL_per_cue = dict.fromkeys(fbs_all_cues.keys())\n",
#     304     "    \n",
#     305     "    def set_dataset(self, fbs_all_cues, trialNo_all_cues):\n",
#     306     "        self.fbs_all_cues = fbs_all_cues\n",
#     307     "        self.trialNo_all_cues = trialNo_all_cues\n",
#     308     "        self.p_hit_all_cues = self.get_empty_dict(fbs_all_cues)\n",
#     309     "        self.vt_all_cues = self.get_empty_dict(fbs_all_cues)\n",
#     310     "        self.pe_all_cues = self.get_empty_dict(fbs_all_cues)\n",
#     311     "        self.isHit_all_cues = self.get_empty_dict(fbs_all_cues)\n",
#     312     "        self.nLLs_all_cues = self.get_empty_dict(fbs_all_cues)\n",
#     313     "        self.total_nLL_per_cue = dict.fromkeys(fbs_all_cues.keys())\n",
#     314     "        \n",
#     315     "    def set_param_values(self, param_values):\n",
#     316     "        self.param_values = param_values\n",
#     317     "        \n",
#     318     "    def get_empty_dict(self, fbs_all_cues):\n",
#     319     "        tmp = dict.fromkeys(fbs_all_cues.keys())\n",
#     320     "        _, rand_fb = random.choice(list(fbs_all_cues.items()))\n",
#     321     "        self.Ntrials_per_cue = len(rand_fb)\n",
#     322     "        for cue in tmp.keys():\n",
#     323     "            tmp[cue] = np.empty(len(rand_fb), dtype=object)\n",
#     324     "        return tmp\n",
#     325     "\n",
#     326     "    def compute_nLL_per_cue(self, p_hit_all_cues, hits_all_cues):\n",
#     327     "        \n",
#     328     "        for cue, p_hit in p_hit_all_cues.items():\n",
#     329     "            \n",
#     330     "            for ind, f_x in enumerate(p_hit):\n",
#     331     "                \n",
#     332     "                y = hits_all_cues[cue][ind]\n",
#     333     "                \n",
#     334     "                # logistic reg cost function\n",
#     335     "                self.nLLs_all_cues[cue][ind] = - y * np.log(f_x) - (1-y) * np.log(1-f_x)\n",
#     336     "            \n",
#     337     "            self.total_nLL_per_cue[cue] = sum(self.nLLs_all_cues[cue])\n",
#     338     "        \n",
#     339     "    \n",
#     340     "    def total_nLL(self, param_values):\n",
#     341     "        \n",
#     342     "        # set parameter values\n",
#     343     "        self.set_param_values(param_values)\n",
#     344     "        \n",
#     345     "        # run model\n",
#     346     "        self.run_model(sim_behav=0)\n",
#     347     "        \n",
#     348     "        # compute nLL per cue TODO change the sim_hits\n",
#     349     "        self.compute_nLL_per_cue(self.p_hit_all_cues, self.isHit_all_cues)\n",
#     350     "        \n",
#     351     "        # total\n",
#     352     "        total_nLL = sum(self.total_nLL_per_cue.values())\n",
#     353     "        \n",
#     354     "        return total_nLL\n",
#     355     "    \n",
#     356     "    \n",
#     357     "    def fit(self, param_lower_bounds, param_upper_bounds, n_iterations, method='TNC'):\n",
#     358     "        \n",
#     359     "        # compute sequence of parameter bounds\n",
#     360     "        bounds = [[low,up] for low, up in zip(param_lower_bounds, param_upper_bounds)]\n",
#     361     "                \n",
#     362     "        # init\n",
#     363     "        mat_min_nLL=[]\n",
#     364     "        mat_best_params=[]\n",
#     365     "        \n",
#     366     "        for i in range(0, n_iterations):\n",
#     367     "            \n",
#     368     "            # define the starting point as a random sample from the domain\n",
#     369     "            initial_guess = [np.random.uniform(bound[0],bound[1],1) for bound in bounds]\n",
#     370     "            \n",
#     371     "            # find the min likelihood \n",
#     372     "            result = minimize(self.total_nLL, initial_guess, method = method, bounds = bounds, \n",
#     373     "                              options={'xtol': 1e-8, 'disp': False})\n",
#     374     "\n",
#     375     "            # store min_nLL and parameters\n",
#     376     "            mat_min_nLL.append(result.fun)\n",
#     377     "            mat_best_params.append(result.x)\n",
#     378     "\n",
#     379     "        # Find best params\n",
#     380     "        ind = np.argmin(mat_min_nLL)\n",
#     381     "        best_params = mat_best_params[ind]\n",
#     382     "\n",
#     383     "        # Compute best LL \n",
#     384     "        nLL = self.total_nLL(best_params)\n",
# --> 385     "        \n",
#     386     "        # Store\n",
#     387     "        self.nLL = nLL\n",
#     388     "        \n",
#     389     "        return best_params, nLL\n",
#     390     "            \n",
#     391     "                    \n",
#     392     "    def run_model(self, sim_behav):\n",
#     393     "        \n",
#     394     "        # set v0 to 0 or get its value if its a free parameter\n",
#     395     "        v0 = 0 if 'v0' not in self.param_names else self.param_values[self.param_names.index('v0')]\n",
#     396     "        \n",
#     397     "        for cue in self.fbs_all_cues.keys():\n",
#     398     "            \n",
#     399     "            # t = 0\n",
#     400     "            self.vt_all_cues[cue][0] = v0\n",
#     401     "\n",
#     402     "            for t, trial in zip(range(0, self.Ntrials_per_cue), self.trialNo_all_cues[cue]):\n",
#     403     "                \n",
#     404     "                # make a decision\n",
#     405     "                self.p_hit_all_cues[cue][t] = self.dec_fct(self.vt_all_cues[cue][t], trial, self.param_names, self.param_values)\n",
#     406     "                \n",
#     407     "                if sim_behav == 1:\n",
#     408     "                    #self.sim_hits_all_cues[cue][t] = 1 if self.p_hit_all_cues[cue][t] >= 0.5 else 0\n",
#     409     "                    self.isHit_all_cues[cue][t] = float(bernoulli.rvs(self.p_hit_all_cues[cue][t], size=1))\n",
#     410     "                    \n",
#     411     "                # compute PE and new v\n",
#     412     "                vt, pe = self.value_fct(vt = self.vt_all_cues[cue][t], isHit = self.isHit_all_cues[cue][t], fb = self.fbs_all_cues[cue][t], \n",
#     413     "                                        param_names = self.param_names, param_values = self.param_values)\n",
#     414     "                self.pe_all_cues[cue][t] = pe\n",
#     415     "\n",
#     416     "                # update v\n",
#     417     "                if t < (self.Ntrials_per_cue-1):\n",
#     418     "                    self.vt_all_cues[cue][t+1] = vt"
#     419    ]
#     420   },
#     421   {
#     422    "cell_type": "markdown",
#     423    "id": "e726d341-3deb-4377-a71c-bd9a6a5c0a7d",
#     424    "metadata": {},
#     425    "source": [
#     426     "## Other"
#     427    ]
#     428   },
#     429   {
#     430    "cell_type": "code",
#     431    "execution_count": 91,
#     432    "id": "048715f2-0fc1-436c-8f9c-9026370ff06a",
#     433    "metadata": {},
#     434    "outputs": [],
#     435    "source": [
#     436     "def fit_model_to_data(uniqueIDs, mod_info, param_lower_bounds, param_upper_bounds, all_users_folder):\n",
#     437     "    \n",
#     438     "    # Fit\n",
#     439     "    all_users = {}\n",
#     440     "    p_hit_per_trial = pd.DataFrame([])\n",
#     441     "    ev_per_trial = pd.DataFrame([])\n",
#     442     "\n",
#     443     "    for n_part,ID in enumerate(uniqueIDs): \n",
#     444     "\n",
#     445     "        # Get data\n",
#     446     "        user_folder = 'data/user_' + ID + '/'\n",
#     447     "        df2_cf = pd.read_pickle(user_folder + 'df2_cf.pkl')\n",
#     448     "        isHit_all_cues, fbs_all_cues, trialNo_all_cues = extract_hits_fbs(df2_cf)\n",
#     449     "\n",
#     450     "        # Create a new Model object\n",
#     451     "        mod = Model(mod_name = mod_info['name'],\n",
#     452     "                    value_fct = mod_info['value_fct'], \n",
#     453     "                    dec_fct = mod_info['dec_fct'], \n",
#     454     "                    param_names = mod_info['param_names'])\n",
#     455     "\n",
#     456     "        # Input data to model\n",
#     457     "        mod.set_part_data(ID, fbs_all_cues, isHit_all_cues, trialNo_all_cues)\n",
#     458     "\n",
#     459     "        # Fit model\n",
#     460     "        mod.fit(param_lower_bounds, param_upper_bounds, n_iterations=5)\n",
#     461     "\n",
#     462     "        # Nested dictionnary user data\n",
#     463     "        all_users[n_part] = {}\n",
#     464     "        all_users[n_part]['ID'] = mod.ID\n",
#     465     "        all_users[n_part]['nLL'] = mod.nLL\n",
#     466     "        all_users[n_part]['Nparams'] = len(mod.param_names)\n",
#     467     "\n",
#     468     "        for i in range(0,len(mod.param_names)):\n",
#     469     "            all_users[n_part][mod.param_names[i]] = mod.param_values[i]\n",
#     470     "\n",
#     471     "        # Concatenated model predictions: p hit\n",
#     472     "        tmp = pd.DataFrame(mod.p_hit_all_cues).transpose()\n",
#     473     "        tmp.columns = tmp.columns + 1\n",
#     474     "        tmp = tmp.reset_index().rename(columns = {'index': 'Cue'})\n",
#     475     "        tmp.insert(0,'ID',ID)\n",
#     476     "        p_hit_per_trial = pd.concat([tmp, p_hit_per_trial], axis=0)\n",
#     477     "\n",
#     478     "        # Concatenated model predictions: EVs\n",
#     479     "        tmp = pd.DataFrame(mod.vt_all_cues).transpose()\n",
#     480     "        tmp.columns = tmp.columns+1\n",
#     481     "        tmp = tmp.reset_index().rename(columns = {'index': 'Cue'})\n",
#     482     "        tmp.insert(0,'ID',ID)\n",
#     483     "        ev_per_trial = pd.concat([tmp, ev_per_trial], axis = 0)\n",
#     484     "\n",
#     485     "    # Save mod LLs and parameter values\n",
#     486     "    mod_fit = pd.DataFrame(all_users).transpose()\n",
#     487     "    mod_fit.to_pickle(all_users_folder + 'mod_param_fits.pkl')\n",
#     488     "\n",
#     489     "    # Save mod predictions\n",
#     490     "    p_hit_per_trial = p_hit_per_trial.sort_values(by ='ID').reset_index(drop = True)\n",
#     491     "    p_hit_per_trial.to_pickle(all_users_folder + 'mod_p_hit_per_trial.pkl')\n",
#     492     "    ev_per_trial = ev_per_trial.sort_values(by ='ID').reset_index(drop = True)\n",
#     493     "    ev_per_trial.to_pickle(all_users_folder + 'mod_ev_per_trial.pkl')"
#     494    ]
#     495   },
#     496   {
#     497    "cell_type": "code",
#     498    "execution_count": 63,
#     499    "id": "d01cef4c-9bd6-41b1-b964-f1d620aae7fe",
#     500    "metadata": {},
#     501    "outputs": [],
#     502    "source": [
#     503     "def reformat_param_lists(all_sim_param_values, all_fit_param_values, mod_info):\n",
#     504     "    \n",
#     505     "    df_sim = pd.DataFrame(all_sim_param_values, columns = mod_info['param_names'])\n",
#     506     "    df_sim.insert(0, 'Type', 'Sim')\n",
#     507     "    df_sim = df_sim.rename_axis('simID').reset_index()\n",
#     508     "\n",
#     509     "    df_fit = pd.DataFrame(all_fit_param_values, columns = mod_info['param_names'])\n",
#     510     "    df_fit.insert(0, 'Type', 'Fit')\n",
#     511     "    df_fit = df_fit.rename_axis('simID').reset_index()\n",
#     512     "    \n",
#     513     "    df = pd.concat([df_sim, df_fit])\n",
#     514     "    df.sort_values(by='simID', ascending=True, inplace = True)\n",
#     515     "    df.reset_index(inplace = True, drop = True)\n",
#     516     "    \n",
#     517     "    return df"
#     518    ]
#     519   },
#     520   {
#     521    "cell_type": "code",
#     522    "execution_count": 64,
#     523    "id": "00149e8e-e89f-43c7-bc3a-24d6243ba097",
#     524    "metadata": {},
#     525    "outputs": [],
#     526    "source": [
#     527     "def extract_hits_fbs(df):\n",
#     528     "    \n",
#     529     "    isHit_all_cues = {}\n",
#     530     "    fbs_all_cues = {}\n",
#     531     "    trialNo_all_cues = {}\n",
#     532     "        \n",
#     533     "    for cue in ['HR', 'LR', 'HP', 'LP']:\n",
#     534     "\n",
#     535     "        # Extract cue data\n",
#     536     "        cue_data_tmp = df[df['Code']==('Cue_' + cue)] \n",
#     537     "\n",
#     538     "        # Create a cue trial column\n",
#     539     "        cue_data_tmp.insert(0, \"CueTrial\", list(range(1,len(cue_data_tmp)+1)))\n",
#     540     "\n",
#     541     "        # Store all in dictionnaries\n",
#     542     "        isHit_all_cues[cue]=cue_data_tmp['isHit'].tolist()\n",
#     543     "        fbs_all_cues[cue]=cue_data_tmp['FBs'].tolist()\n",
#     544     "        trialNo_all_cues[cue]=cue_data_tmp['Trial'].tolist()\n",
#     545     "        \n",
#     546     "    return isHit_all_cues, fbs_all_cues, trialNo_all_cues"
#     547    ]
#     548   },
#     549   {
#     550    "cell_type": "code",
#     551    "execution_count": 65,
#     552    "id": "4bacec63-9ad3-430d-9a1f-314d77dcc7e7",
#     553    "metadata": {},
#     554    "outputs": [],
#     555    "source": [
#     556     "def extract_rand_dataset():\n",
#     557     "    \n",
#     558     "    all_users_folder = 'data/all_users/'\n",
#     559     "\n",
#     560     "    # Load IDs\n",
#     561     "    with open('uniqueIDs.pkl', 'rb') as f:\n",
#     562     "        uniqueIDs = pickle.load(f)\n",
#     563     "\n",
#     564     "    # Extract random data set\n",
#     565     "    random.shuffle(uniqueIDs)\n",
#     566     "    ID = uniqueIDs[0]\n",
#     567     "    user_folder = 'data/user_' + ID + '/'\n",
#     568     "    df2_cf = pd.read_pickle(user_folder + 'df2_cf.pkl')\n",
#     569     "    _, fbs_all_cues, trialNo_all_cues = extract_hits_fbs(df2_cf)\n",
#     570     "    #print('Dataset from ID =',ID)\n",
#     571     "    \n",
#     572     "    return fbs_all_cues, trialNo_all_cues"
#     573    ]
#     574   },
#     575   {
#     576    "cell_type": "code",
#     577    "execution_count": 66,
#     578    "id": "d60d4b5e-2234-4479-8887-18fbf59e7478",
#     579    "metadata": {},
#     580    "outputs": [],
#     581    "source": [
#     582     "def sim_fit_model(mod_info, param_lower_bounds, param_upper_bounds, Nsim, all_users_folder):\n",
#     583     "\n",
#     584     "    # Create a new Model object\n",
#     585     "    mod = Model(mod_name = mod_info['name'], \n",
#     586     "                value_fct = mod_info['value_fct'], \n",
#     587     "                dec_fct = mod_info['dec_fct'], \n",
#     588     "                param_names = mod_info['param_names'])\n",
#     589     "    \n",
#     590     "    # print model info\n",
#     591     "    print(repr(mod))\n",
#     592     "\n",
#     593     "    # init\n",
#     594     "    all_sim_param_values = []\n",
#     595     "    all_fit_param_values = []\n",
#     596     "    \n",
#     597     "    # bounds\n",
#     598     "    bounds = [[low,up] for low, up in zip(param_lower_bounds, param_upper_bounds)]\n",
#     599     "\n",
#     600     "    for sim_id in range(0, Nsim):\n",
#     601     "\n",
#     602     "        if sim_id>4 and sim_id%int(round(Nsim/4))==0:\n",
#     603     "            print(sim_id)\n",
#     604     "\n",
#     605     "        # extract random dataset and set\n",
#     606     "        fbs_all_cues, trialNo_all_cues = extract_rand_dataset()\n",
#     607     "        mod.set_dataset(fbs_all_cues, trialNo_all_cues)\n",
#     608     "\n",
#     609     "        # random param values for simulation\n",
#     610     "        generating_param_values = [np.random.uniform(bound[0],bound[1],1) for bound in bounds]\n",
#     611     "\n",
#     612     "        # set param values\n",
#     613     "        mod.set_param_values(generating_param_values)\n",
#     614     "\n",
#     615     "        # simulate behav\n",
#     616     "        mod.run_model(sim_behav=1)\n",
#     617     "\n",
#     618     "        # fit\n",
#     619     "        best_params, _ = mod.fit(param_lower_bounds, param_upper_bounds, n_iterations = 10)\n",
#     620     "\n",
#     621     "        # store\n",
#     622     "        all_sim_param_values.append(np.concatenate(generating_param_values, axis=0))\n",
#     623     "        all_fit_param_values.append(best_params)\n",
#     624     "\n",
#     625     "    # Reformat\n",
#     626     "    df = reformat_param_lists(all_sim_param_values, all_fit_param_values, mod_info)\n",
#     627     "\n",
#     628     "    # Save\n",
#     629     "    filename = all_users_folder + 'sim_refit/' + mod_info['name'] + '.pkl'\n",
#     630     "    df.to_pickle(filename)\n",
#     631     "    print('DONE. Saved to: ', filename.strip())\n",
#     632     "    \n",
#     633     "    return mod"
#     634    ]
#     635   },
#     636   {
#     637    "cell_type": "markdown",
#     638    "id": "5aa9e6c1-9e06-4668-aa56-7719a4163372",
#     639    "metadata": {},
#     640    "source": [
#     641     "## Value function"
#     642    ]
#     643   },
#     644   {
#     645    "cell_type": "code",
#     646    "execution_count": 73,
#     647    "id": "25d19586-61b6-45fe-ab0e-ba6f4f729374",
#     648    "metadata": {},
#     649    "outputs": [],
#     650    "source": [
#     651     "def rescorla_wagner_2LR_1t(vt, isHit, fb, param_names, param_values):   \n",
#     652     "    \n",
#     653     "    # set alpha to 1 or get its value if its a free parameter\n",
#     654     "    alpha_rew = param_values[param_names.index('alpha_rew')]\n",
#     655     "    alpha_pun = param_values[param_names.index('alpha_pun')]\n",
#     656     "    \n",
#     657     "    pe = fb - vt\n",
#     658     "\n",
#     659     "    if isHit == 1:\n",
#     660     "        if fb > 0:\n",
#     661     "            vt = vt + alpha_rew * pe\n",
#     662     "        elif fb < 0:\n",
#     663     "            vt = vt + alpha_pun * pe \n",
#     664     "    \n",
#     665     "    elif isHit == 0:\n",
#     666     "        pe = np.nan\n",
#     667     "        \n",
#     668     "    return vt, pe"
#     669    ]
#     670   },
#     671   {
#     672    "cell_type": "code",
#     673    "execution_count": 67,
#     674    "id": "cf4247ec-e13f-41c1-9a7f-b6d085e50080",
#     675    "metadata": {},
#     676    "outputs": [],
#     677    "source": [
#     678     "def rescorla_wagner_1t(vt, isHit, fb, param_names, param_values):   \n",
#     679     "    \n",
#     680     "    # set alpha to 1 or get its value if its a free parameter\n",
#     681     "    alpha = 0.1 if 'alpha' not in param_names else param_values[param_names.index('alpha')]\n",
#     682     "    \n",
#     683     "    if isHit == 1:\n",
#     684     "        pe = fb - vt\n",
#     685     "        vt = vt + alpha * pe \n",
#     686     "    \n",
#     687     "    elif isHit == 0:\n",
#     688     "        pe = np.nan\n",
#     689     "        \n",
#     690     "    return vt, pe"
#     691    ]
#     692   },
#     693   {
#     694    "cell_type": "markdown",
#     695    "id": "8d4d09ee-3409-412e-aec9-f6383fb791d1",
#     696    "metadata": {},
#     697    "source": [
#     698     "## Decision function"
#     699    ]
#     700   },
#     701   {
#     702    "cell_type": "code",
#     703    "execution_count": 71,
#     704    "id": "6e708fe5-1473-4238-b15b-3abbd635df83",
#     705    "metadata": {},
#     706    "outputs": [],
#     707    "source": [
#     708     "def my_softmax_1t(vt, trial, param_names, param_values): \n",
#     709     "    \n",
#     710     "    # set beta to 1 or get its value if its a free parameter\n",
#     711     "    # same for press bias pi to 0, and for shrinking press bias pi_t\n",
#     712     "    beta = 1 if 'beta' not in param_names else param_values[param_names.index('beta')]\n",
#     713     "    pi = 0 if 'pi' not in param_names else param_values[param_names.index('pi')]\n",
#     714     "    pi_t = 0 if 'pi_t' not in param_names else param_values[param_names.index('pi_t')]\n",
#     715     "    \n",
#     716     "    # normalise the trial, start at 1 at the new block\n",
#     717     "    norm_trial = (trial-56) if trial>56 else trial\n",
#     718     "    shrink = (56 - norm_trial)/56\n",
#     719     "        \n",
#     720     "    v_no_hit = 0\n",
#     721     "    v_hit = vt + pi + pi_t*shrink\n",
#     722     "    diff = v_no_hit - v_hit\n",
#     723     "    \n",
#     724     "    p_hit = 1 / (1 + np.exp(beta * diff))\n",
#     725     "            \n",
#     726     "    return p_hit"
#     727    ]
#     728   },
#     729   {
#     730    "cell_type": "code",
#     731    "execution_count": null,
#     732    "id": "f0366188-6827-4e52-9b5e-a3bc6f0ebecd",
#     733    "metadata": {},
#     734    "outputs": [],
#     735    "source": []
#     736   }
#     737  ],
#     738  "metadata": {
#     739   "kernelspec": {
#     740    "display_name": "Python 3 (ipykernel)",
#     741    "language": "python",
#     742    "name": "python3"
#     743   },
#     744   "language_info": {
#     745    "codemirror_mode": {
#     746     "name": "ipython",
#     747     "version": 3
#     748    },
#     749    "file_extension": ".py",
#     750    "mimetype": "text/x-python",
#     751    "name": "python",
#     752    "nbconvert_exporter": "python",
#     753    "pygments_lexer": "ipython3",
#     754    "version": "3.8.12"
#     755   }
#     756  },
#     757  "nbformat": 4,
#     758  "nbformat_minor": 5
#     759 }
#
# File /Volumes/GoogleDrive/Mon Drive/PAT/data_analysis/functions_new.ipynb:310, in fit(self, param_lower_bounds, param_upper_bounds, n_iterations, method)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 85,
#       6    "id": "a61108ed-fb3a-4c22-b0d5-c7046ffa1c71",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "import numpy as np\n",
#      11     "import pandas as pd\n",
#      12     "import pickle\n",
#      13     "import random\n",
#      14     "from scipy.optimize import minimize\n",
#      15     "from scipy.stats import pearsonr, bernoulli\n",
#      16     "import matplotlib.pyplot as plt\n",
#      17     "import seaborn as sns\n",
#      18     "import math\n",
#      19     "import ptitprince as pt # rainplot"
#      20    ]
#      21   },
#      22   {
#      23    "cell_type": "markdown",
#      24    "id": "c1521503-0078-4f97-8797-934f1f052c4f",
#      25    "metadata": {},
#      26    "source": [
#      27     "## Plot"
#      28    ]
#      29   },
#      30   {
#      31    "cell_type": "code",
#      32    "execution_count": 88,
#      33    "id": "25470086-7631-4ff6-9d93-01d68ce4af64",
#      34    "metadata": {},
#      35    "outputs": [],
#      36    "source": [
#      37     "def fig_modelpred_on_behav(ev_per_trial, p_hit_per_trial, all_users_folder):\n",
#      38     "\n",
#      39     "    # Timepoints\n",
#      40     "    window_size = 16\n",
#      41     "    N_trials = 112\n",
#      42     "    timepoints = ['t'+ str(t+1) for t in range(int(N_trials/window_size))]\n",
#      43     "\n",
#      44     "    # Load behaviour and compute stats\n",
#      45     "    hit_perc_per_t = pd.read_pickle(all_users_folder + 'hit_perc_per_t/hit_perc_per_t_w' + str(window_size) + '.pkl');\n",
#      46     "    hit_perc_per_t.drop('ID', axis=1, inplace=True);\n",
#      47     "    stats_hits_perc_per_t = hit_perc_per_t.groupby('Code').agg(['mean', 'var']).T.swaplevel(axis=0);\n",
#      48     "\n",
#      49     "    # Load model predictions and compute stats\n",
#      50     "    ev_per_trial.drop('ID', axis=1, inplace=True);\n",
#      51     "    stats_ev_per_trial = ev_per_trial.groupby('Cue').agg(['mean', 'var']).T.swaplevel(axis=0)\n",
#      52     "    stats_ev_per_trial.columns = 'Cue_'+stats_ev_per_trial.columns\n",
#      53     "\n",
#      54     "    p_hit_per_trial.drop('ID', axis=1, inplace=True);\n",
#      55     "    stats_p_hit_per_trial = p_hit_per_trial.groupby('Cue').agg(['mean', 'var']).T.swaplevel(axis=0)\n",
#      56     "    stats_p_hit_per_trial.columns = 'Cue_'+stats_p_hit_per_trial.columns\n",
#      57     "\n",
#      58     "    # Plot\n",
#      59     "    f, axs = plt.subplots(2, 1, figsize=(10, 6), dpi=80)\n",
#      60     "    plt.subplots_adjust(hspace = 0.4)\n",
#      61     "\n",
#      62     "    x_mod = np.arange(len(stats_ev_per_trial.loc['mean']))+1\n",
#      63     "    x_behav = np.arange(len(timepoints))*4+4\n",
#      64     "\n",
#      65     "    for cue, color, alpha in zip(['Cue_HP', 'Cue_LP', 'Cue_LR', 'Cue_HR'], ['red', 'red', 'green', 'green'], [0.6, 0.3, 0.3, 0.6]):\n",
#      66     "        # Hit probabilites\n",
#      67     "        m=axs[0].plot(x_mod, stats_p_hit_per_trial.loc['mean'][cue], '.-', color=color, alpha=alpha);\n",
#      68     "        # Behaviour: sliding average\n",
#      69     "        b=axs[0].plot(x_behav, stats_hits_perc_per_t.loc['mean'][cue], '.-', color='gray', alpha=alpha);\n",
#      70     "        # Expected values\n",
#      71     "        m=axs[1].plot(x_mod, stats_ev_per_trial.loc['mean'][cue], '.-', color=color, alpha=alpha);\n",
#      72     "\n",
#      73     "    for ax in axs:\n",
#      74     "        ax.grid(axis='x', color='0.95');\n",
#      75     "        ax.set_xticks(x_mod);\n",
#      76     "    \n",
#      77     "    axs[0].set_title('Model probability of hit', fontsize=16);\n",
#      78     "    axs[1].set_title('Model expected values', fontsize=16);\n",
#      79     "    \n",
#      80     "    axs[0].set_ylabel(\"Hit [%]\", fontsize=16);\n",
#      81     "    axs[1].set_ylabel(\"Values\", fontsize=16);\n",
#      82     "    \n",
#      83     "    axs[0].set_ylim([0,1]);\n",
#      84     "    axs[1].set_ylim([-3,3]);\n",
#      85     "    \n",
#      86     "    axs[0].legend(b, {'Behaviour'})\n",
#      87     "    \n",
#      88     "    plt.show()"
#      89    ]
#      90   },
#      91   {
#      92    "cell_type": "code",
#      93    "execution_count": 87,
#      94    "id": "2ebec1bb-c224-4a23-93b3-d2c188f2e43f",
#      95    "metadata": {},
#      96    "outputs": [],
#      97    "source": [
#      98     "def plot_model_parameters(data_mod, param_names):\n",
#      99     "    \n",
#     100     "    Nparam = len(param_names)\n",
#     101     "    \n",
#     102     "    if Nparam<=3:\n",
#     103     "        f, axs = plt.subplots(1, Nparam, figsize=(Nparam*6, 5))\n",
#     104     "    elif Nparam==4:\n",
#     105     "        f, axs = plt.subplots(2, 2, figsize=(2*6, 2*5))\n",
#     106     "        axs = axs.reshape(-1)\n",
#     107     "    else:\n",
#     108     "        f, axs = plt.subplots(2, 3, figsize=(3*6, 2*5))\n",
#     109     "        axs = axs.reshape(-1)\n",
#     110     "        \n",
#     111     "    plt.subplots_adjust(hspace = 0.3)\n",
#     112     "        \n",
#     113     "    pal = sns.color_palette(n_colors=1)\n",
#     114     "    \n",
#     115     "    if Nparam == 1:\n",
#     116     "        ax, param = axs, param_names[0]\n",
#     117     "        y = data_mod[param].squeeze().tolist()\n",
#     118     "        pt.half_violinplot(ax=ax, x = y, palette = pal, bw = .2, cut = 0., scale = \"area\", width = .6, inner = None, orient = 'h')\n",
#     119     "        sns.stripplot(ax=ax, x = y, palette = pal, edgecolor = \"white\", size = 5, jitter = 1, zorder = 0, orient = 'h', alpha=.35)\n",
#     120     "        sns.boxplot(x = y, saturation=1, showfliers=False, width=0.15, boxprops={'zorder': 3, 'facecolor': 'none'}, ax=ax)\n",
#     121     "        ax.set_title('Parameter: ' + param, fontsize=18)\n",
#     122     "        ax.set_xlabel('Best fit parameter value', fontsize=16)\n",
#     123     "\n",
#     124     "    else:\n",
#     125     "        for ax, param in zip(axs, param_names):\n",
#     126     "            y = data_mod[param].tolist()\n",
#     127     "            # plot clouds\n",
#     128     "            pt.half_violinplot(ax=ax, x = y, palette = pal, bw = .2, cut = 0., scale = \"area\", width = .6, inner = None, orient = 'h')\n",
#     129     "            # add rain\n",
#     130     "            sns.stripplot(ax=ax, x = y, palette = pal, edgecolor = \"white\", size = 5, jitter = 1, zorder = 0, orient = 'h', alpha=.35)\n",
#     131     "            sns.boxplot(x = y, saturation=1, showfliers=False, width=0.15, boxprops={'zorder': 3, 'facecolor': 'none'}, ax=ax)\n",
#     132     "            # Makeup\n",
#     133     "            ax.set_title('Parameter: ' + param, fontsize=18)\n",
#     134     "            ax.set_xlabel('Best fit parameter value', fontsize=16)\n",
#     135     "\n",
#     136     "    plt.show()"
#     137    ]
#     138   },
#     139   {
#     140    "cell_type": "code",
#     141    "execution_count": 2,
#     142    "id": "cd22618d-6a43-4053-addc-f66bd19ae031",
#     143    "metadata": {},
#     144    "outputs": [],
#     145    "source": [
#     146     "def plot_correlation(title, x, y, data, ax, text_pos, xlabel, ylabel, xlim, ylim):\n",
#     147     "        \n",
#     148     "    # Initialise figue\n",
#     149     "    ax.set_title(title, fontsize = 22)\n",
#     150     "\n",
#     151     "    # Scatter plot\n",
#     152     "    sns.scatterplot( x = x, y = y, data = data, ax = ax);\n",
#     153     "\n",
#     154     "    # Linear regression line\n",
#     155     "    sns.regplot(x = x, y = y, data = data, ax = ax);\n",
#     156     "    \n",
#     157     "    # Plot horizontal line\n",
#     158     "    ax.axhline(y=0, color='k', linestyle=':')\n",
#     159     "\n",
#     160     "    # Compute correlation stats (r and p values)\n",
#     161     "    r, p = pearsonr(data[x], data[y])\n",
#     162     "    \n",
#     163     "    # Write stats on fig\n",
#     164     "    if p<0.01:\n",
#     165     "        ax.text(text_pos[0], text_pos[1], 'r={:.2f} \\np<0.01'.format(r, p), transform=ax.transAxes, fontsize=16)\n",
#     166     "    else:    \n",
#     167     "        ax.text(text_pos[0], text_pos[1], 'r={:.2f} \\np={:.2g}'.format(r, p), transform=ax.transAxes, fontsize=16)\n",
#     168     "    \n",
#     169     "    # Properties\n",
#     170     "    ax.set_ylabel(ylabel, fontsize=15)\n",
#     171     "    ax.set_ylim(bottom=ylim[0], top=ylim[1])\n",
#     172     "    \n",
#     173     "    ax.set_xlabel(xlabel, fontsize=15)\n",
#     174     "    ax.set_xlim(left=xlim[0], right=xlim[1])"
#     175    ]
#     176   },
#     177   {
#     178    "cell_type": "code",
#     179    "execution_count": 43,
#     180    "id": "752cfc61-37ae-45e9-ba77-dc29f33b1ae3",
#     181    "metadata": {},
#     182    "outputs": [],
#     183    "source": [
#     184     "def plot_param_recov_correlations(df):\n",
#     185     "    \n",
#     186     "    # get Param names\n",
#     187     "    param_names = df.columns[2::].tolist()\n",
#     188     "\n",
#     189     "    Nparam = len(param_names)\n",
#     190     "\n",
#     191     "    if Nparam<=3:\n",
#     192     "        #f, axs = plt.subplots(1, Nparam, figsize=(Nparam*6, 5))\n",
#     193     "        f, axs = plt.subplots(1, Nparam, figsize=(Nparam*4, 3))\n",
#     194     "    elif Nparam==4:\n",
#     195     "        f, axs = plt.subplots(2, 2, figsize=(2*6, 2*5))\n",
#     196     "        axs = axs.reshape(-1)\n",
#     197     "    else:\n",
#     198     "        f, axs = plt.subplots(2, 3, figsize=(3*6, 2*5))\n",
#     199     "        axs = axs.reshape(-1)\n",
#     200     "\n",
#     201     "    plt.subplots_adjust(hspace = 0.3)\n",
#     202     "\n",
#     203     "    for i, param in enumerate(param_names):\n",
#     204     "\n",
#     205     "        lims = [math.floor(df[param].min()), math.ceil(df[param].max())]\n",
#     206     "\n",
#     207     "        df_tmp = df.pivot(index = 'simID', columns = 'Type', values=param)\n",
#     208     "        \n",
#     209     "        ax = axs if Nparam==1 else axs[i]\n",
#     210     "\n",
#     211     "        plot_correlation(title=param, x='Fit', y='Sim',\n",
#     212     "                         data=df_tmp, ax=ax, text_pos=[.2,.8], \n",
#     213     "                         xlabel='Fitted', ylabel='Simulated', xlim=lims, ylim=lims)\n",
#     214     "    plt.show()"
#     215    ]
#     216   },
#     217   {
#     218    "cell_type": "code",
#     219    "execution_count": 44,
#     220    "id": "3cc4a79a-7ffe-422e-b508-9e0ba6a66029",
#     221    "metadata": {},
#     222    "outputs": [],
#     223    "source": [
#     224     "def plot_param_recov_conf_matrix(df):\n",
#     225     "    \n",
#     226     "    #f, axs = plt.subplots(1, 1, figsize=(7, 6))\n",
#     227     "    f, axs = plt.subplots(1, 1, figsize=(4, 3))\n",
#     228     "\n",
#     229     "    # get Param names\n",
#     230     "    param_names = df.columns[2::].tolist()\n",
#     231     "\n",
#     232     "    # Initialise matrices of nans\n",
#     233     "    Nparam = len(param_names)\n",
#     234     "    confusion_mat = np.empty((Nparam, Nparam))\n",
#     235     "    confusion_mat[:] = np.NaN\n",
#     236     "\n",
#     237     "    # Store pearson correlations\n",
#     238     "    for i_sim, param_sim_name in enumerate(param_names):\n",
#     239     "        for i_fit, param_fit_name in enumerate(param_names):\n",
#     240     "            param_sim_values = df[df['Type']=='Sim'][param_sim_name]\n",
#     241     "            param_fit_values = df[df['Type']=='Fit'][param_fit_name]\n",
#     242     "            corr, _ = pearsonr(param_sim_values, param_fit_values)\n",
#     243     "            confusion_mat[i_sim, i_fit] = corr\n",
#     244     "            #print('sim: ' + param_sim_name + ' fit: ' + param_fit_name)\n",
#     245     "            #print(corr)\n",
#     246     "\n",
#     247     "    # Plot confusion matrix\n",
#     248     "    ax = sns.heatmap(confusion_mat.T, vmin=-1, vmax=1, annot=True, annot_kws={\"fontsize\":12, \"weight\":\"normal\"}, cmap='coolwarm')\n",
# ...
#     396     "        \n",
#     397     "        for cue in self.fbs_all_cues.keys():\n",
#     398     "            \n",
#     399     "            # t = 0\n",
#     400     "            self.vt_all_cues[cue][0] = v0\n",
#     401     "\n",
#     402     "            for t, trial in zip(range(0, self.Ntrials_per_cue), self.trialNo_all_cues[cue]):\n",
#     403     "                \n",
#     404     "                # make a decision\n",
#     405     "                self.p_hit_all_cues[cue][t] = self.dec_fct(self.vt_all_cues[cue][t], trial, self.param_names, self.param_values)\n",
#     406     "                \n",
#     407     "                if sim_behav == 1:\n",
#     408     "                    #self.sim_hits_all_cues[cue][t] = 1 if self.p_hit_all_cues[cue][t] >= 0.5 else 0\n",
#     409     "                    self.isHit_all_cues[cue][t] = float(bernoulli.rvs(self.p_hit_all_cues[cue][t], size=1))\n",
#     410     "                    \n",
#     411     "                # compute PE and new v\n",
#     412     "                vt, pe = self.value_fct(vt = self.vt_all_cues[cue][t], isHit = self.isHit_all_cues[cue][t], fb = self.fbs_all_cues[cue][t], \n",
#     413     "                                        param_names = self.param_names, param_values = self.param_values)\n",
#     414     "                self.pe_all_cues[cue][t] = pe\n",
#     415     "\n",
#     416     "                # update v\n",
#     417     "                if t < (self.Ntrials_per_cue-1):\n",
#     418     "                    self.vt_all_cues[cue][t+1] = vt"
#     419    ]
#     420   },
#     421   {
#     422    "cell_type": "markdown",
#     423    "id": "e726d341-3deb-4377-a71c-bd9a6a5c0a7d",
#     424    "metadata": {},
#     425    "source": [
#     426     "## Other"
#     427    ]
#     428   },
#     429   {
#     430    "cell_type": "code",
#     431    "execution_count": 91,
#     432    "id": "048715f2-0fc1-436c-8f9c-9026370ff06a",
#     433    "metadata": {},
#     434    "outputs": [],
#     435    "source": [
#     436     "def fit_model_to_data(uniqueIDs, mod_info, param_lower_bounds, param_upper_bounds, all_users_folder):\n",
#     437     "    \n",
#     438     "    # Fit\n",
#     439     "    all_users = {}\n",
#     440     "    p_hit_per_trial = pd.DataFrame([])\n",
#     441     "    ev_per_trial = pd.DataFrame([])\n",
#     442     "\n",
#     443     "    for n_part,ID in enumerate(uniqueIDs): \n",
#     444     "\n",
#     445     "        # Get data\n",
#     446     "        user_folder = 'data/user_' + ID + '/'\n",
#     447     "        df2_cf = pd.read_pickle(user_folder + 'df2_cf.pkl')\n",
#     448     "        isHit_all_cues, fbs_all_cues, trialNo_all_cues = extract_hits_fbs(df2_cf)\n",
#     449     "\n",
#     450     "        # Create a new Model object\n",
#     451     "        mod = Model(mod_name = mod_info['name'],\n",
#     452     "                    value_fct = mod_info['value_fct'], \n",
#     453     "                    dec_fct = mod_info['dec_fct'], \n",
#     454     "                    param_names = mod_info['param_names'])\n",
#     455     "\n",
#     456     "        # Input data to model\n",
#     457     "        mod.set_part_data(ID, fbs_all_cues, isHit_all_cues, trialNo_all_cues)\n",
#     458     "\n",
#     459     "        # Fit model\n",
#     460     "        mod.fit(param_lower_bounds, param_upper_bounds, n_iterations=5)\n",
#     461     "\n",
#     462     "        # Nested dictionnary user data\n",
#     463     "        all_users[n_part] = {}\n",
#     464     "        all_users[n_part]['ID'] = mod.ID\n",
#     465     "        all_users[n_part]['nLL'] = mod.nLL\n",
#     466     "        all_users[n_part]['Nparams'] = len(mod.param_names)\n",
#     467     "\n",
#     468     "        for i in range(0,len(mod.param_names)):\n",
#     469     "            all_users[n_part][mod.param_names[i]] = mod.param_values[i]\n",
#     470     "\n",
#     471     "        # Concatenated model predictions: p hit\n",
#     472     "        tmp = pd.DataFrame(mod.p_hit_all_cues).transpose()\n",
#     473     "        tmp.columns = tmp.columns + 1\n",
#     474     "        tmp = tmp.reset_index().rename(columns = {'index': 'Cue'})\n",
#     475     "        tmp.insert(0,'ID',ID)\n",
#     476     "        p_hit_per_trial = pd.concat([tmp, p_hit_per_trial], axis=0)\n",
#     477     "\n",
#     478     "        # Concatenated model predictions: EVs\n",
#     479     "        tmp = pd.DataFrame(mod.vt_all_cues).transpose()\n",
#     480     "        tmp.columns = tmp.columns+1\n",
#     481     "        tmp = tmp.reset_index().rename(columns = {'index': 'Cue'})\n",
#     482     "        tmp.insert(0,'ID',ID)\n",
#     483     "        ev_per_trial = pd.concat([tmp, ev_per_trial], axis = 0)\n",
#     484     "\n",
#     485     "    # Save mod LLs and parameter values\n",
#     486     "    mod_fit = pd.DataFrame(all_users).transpose()\n",
#     487     "    mod_fit.to_pickle(all_users_folder + 'mod_param_fits.pkl')\n",
#     488     "\n",
#     489     "    # Save mod predictions\n",
#     490     "    p_hit_per_trial = p_hit_per_trial.sort_values(by ='ID').reset_index(drop = True)\n",
#     491     "    p_hit_per_trial.to_pickle(all_users_folder + 'mod_p_hit_per_trial.pkl')\n",
#     492     "    ev_per_trial = ev_per_trial.sort_values(by ='ID').reset_index(drop = True)\n",
#     493     "    ev_per_trial.to_pickle(all_users_folder + 'mod_ev_per_trial.pkl')"
#     494    ]
#     495   },
#     496   {
#     497    "cell_type": "code",
#     498    "execution_count": 63,
#     499    "id": "d01cef4c-9bd6-41b1-b964-f1d620aae7fe",
#     500    "metadata": {},
#     501    "outputs": [],
#     502    "source": [
#     503     "def reformat_param_lists(all_sim_param_values, all_fit_param_values, mod_info):\n",
#     504     "    \n",
#     505     "    df_sim = pd.DataFrame(all_sim_param_values, columns = mod_info['param_names'])\n",
#     506     "    df_sim.insert(0, 'Type', 'Sim')\n",
#     507     "    df_sim = df_sim.rename_axis('simID').reset_index()\n",
#     508     "\n",
#     509     "    df_fit = pd.DataFrame(all_fit_param_values, columns = mod_info['param_names'])\n",
#     510     "    df_fit.insert(0, 'Type', 'Fit')\n",
#     511     "    df_fit = df_fit.rename_axis('simID').reset_index()\n",
#     512     "    \n",
#     513     "    df = pd.concat([df_sim, df_fit])\n",
#     514     "    df.sort_values(by='simID', ascending=True, inplace = True)\n",
#     515     "    df.reset_index(inplace = True, drop = True)\n",
#     516     "    \n",
#     517     "    return df"
#     518    ]
#     519   },
#     520   {
#     521    "cell_type": "code",
#     522    "execution_count": 64,
#     523    "id": "00149e8e-e89f-43c7-bc3a-24d6243ba097",
#     524    "metadata": {},
#     525    "outputs": [],
#     526    "source": [
#     527     "def extract_hits_fbs(df):\n",
#     528     "    \n",
#     529     "    isHit_all_cues = {}\n",
#     530     "    fbs_all_cues = {}\n",
#     531     "    trialNo_all_cues = {}\n",
#     532     "        \n",
#     533     "    for cue in ['HR', 'LR', 'HP', 'LP']:\n",
#     534     "\n",
#     535     "        # Extract cue data\n",
#     536     "        cue_data_tmp = df[df['Code']==('Cue_' + cue)] \n",
#     537     "\n",
#     538     "        # Create a cue trial column\n",
#     539     "        cue_data_tmp.insert(0, \"CueTrial\", list(range(1,len(cue_data_tmp)+1)))\n",
#     540     "\n",
#     541     "        # Store all in dictionnaries\n",
#     542     "        isHit_all_cues[cue]=cue_data_tmp['isHit'].tolist()\n",
#     543     "        fbs_all_cues[cue]=cue_data_tmp['FBs'].tolist()\n",
#     544     "        trialNo_all_cues[cue]=cue_data_tmp['Trial'].tolist()\n",
#     545     "        \n",
#     546     "    return isHit_all_cues, fbs_all_cues, trialNo_all_cues"
#     547    ]
#     548   },
#     549   {
#     550    "cell_type": "code",
#     551    "execution_count": 65,
#     552    "id": "4bacec63-9ad3-430d-9a1f-314d77dcc7e7",
#     553    "metadata": {},
#     554    "outputs": [],
#     555    "source": [
#     556     "def extract_rand_dataset():\n",
#     557     "    \n",
#     558     "    all_users_folder = 'data/all_users/'\n",
#     559     "\n",
#     560     "    # Load IDs\n",
#     561     "    with open('uniqueIDs.pkl', 'rb') as f:\n",
#     562     "        uniqueIDs = pickle.load(f)\n",
#     563     "\n",
#     564     "    # Extract random data set\n",
#     565     "    random.shuffle(uniqueIDs)\n",
#     566     "    ID = uniqueIDs[0]\n",
#     567     "    user_folder = 'data/user_' + ID + '/'\n",
#     568     "    df2_cf = pd.read_pickle(user_folder + 'df2_cf.pkl')\n",
#     569     "    _, fbs_all_cues, trialNo_all_cues = extract_hits_fbs(df2_cf)\n",
#     570     "    #print('Dataset from ID =',ID)\n",
#     571     "    \n",
#     572     "    return fbs_all_cues, trialNo_all_cues"
#     573    ]
#     574   },
#     575   {
#     576    "cell_type": "code",
#     577    "execution_count": 66,
#     578    "id": "d60d4b5e-2234-4479-8887-18fbf59e7478",
#     579    "metadata": {},
#     580    "outputs": [],
#     581    "source": [
#     582     "def sim_fit_model(mod_info, param_lower_bounds, param_upper_bounds, Nsim, all_users_folder):\n",
#     583     "\n",
#     584     "    # Create a new Model object\n",
#     585     "    mod = Model(mod_name = mod_info['name'], \n",
#     586     "                value_fct = mod_info['value_fct'], \n",
#     587     "                dec_fct = mod_info['dec_fct'], \n",
#     588     "                param_names = mod_info['param_names'])\n",
#     589     "    \n",
#     590     "    # print model info\n",
#     591     "    print(repr(mod))\n",
#     592     "\n",
#     593     "    # init\n",
#     594     "    all_sim_param_values = []\n",
#     595     "    all_fit_param_values = []\n",
#     596     "    \n",
#     597     "    # bounds\n",
#     598     "    bounds = [[low,up] for low, up in zip(param_lower_bounds, param_upper_bounds)]\n",
#     599     "\n",
#     600     "    for sim_id in range(0, Nsim):\n",
#     601     "\n",
#     602     "        if sim_id>4 and sim_id%int(round(Nsim/4))==0:\n",
#     603     "            print(sim_id)\n",
#     604     "\n",
#     605     "        # extract random dataset and set\n",
#     606     "        fbs_all_cues, trialNo_all_cues = extract_rand_dataset()\n",
#     607     "        mod.set_dataset(fbs_all_cues, trialNo_all_cues)\n",
#     608     "\n",
#     609     "        # random param values for simulation\n",
#     610     "        generating_param_values = [np.random.uniform(bound[0],bound[1],1) for bound in bounds]\n",
#     611     "\n",
#     612     "        # set param values\n",
#     613     "        mod.set_param_values(generating_param_values)\n",
#     614     "\n",
#     615     "        # simulate behav\n",
#     616     "        mod.run_model(sim_behav=1)\n",
#     617     "\n",
#     618     "        # fit\n",
#     619     "        best_params, _ = mod.fit(param_lower_bounds, param_upper_bounds, n_iterations = 10)\n",
#     620     "\n",
#     621     "        # store\n",
#     622     "        all_sim_param_values.append(np.concatenate(generating_param_values, axis=0))\n",
#     623     "        all_fit_param_values.append(best_params)\n",
#     624     "\n",
#     625     "    # Reformat\n",
#     626     "    df = reformat_param_lists(all_sim_param_values, all_fit_param_values, mod_info)\n",
#     627     "\n",
#     628     "    # Save\n",
#     629     "    filename = all_users_folder + 'sim_refit/' + mod_info['name'] + '.pkl'\n",
#     630     "    df.to_pickle(filename)\n",
#     631     "    print('DONE. Saved to: ', filename.strip())\n",
#     632     "    \n",
#     633     "    return mod"
#     634    ]
#     635   },
#     636   {
#     637    "cell_type": "markdown",
#     638    "id": "5aa9e6c1-9e06-4668-aa56-7719a4163372",
#     639    "metadata": {},
#     640    "source": [
#     641     "## Value function"
#     642    ]
#     643   },
#     644   {
#     645    "cell_type": "code",
#     646    "execution_count": 73,
#     647    "id": "25d19586-61b6-45fe-ab0e-ba6f4f729374",
#     648    "metadata": {},
#     649    "outputs": [],
#     650    "source": [
#     651     "def rescorla_wagner_2LR_1t(vt, isHit, fb, param_names, param_values):   \n",
#     652     "    \n",
#     653     "    # set alpha to 1 or get its value if its a free parameter\n",
#     654     "    alpha_rew = param_values[param_names.index('alpha_rew')]\n",
#     655     "    alpha_pun = param_values[param_names.index('alpha_pun')]\n",
#     656     "    \n",
#     657     "    pe = fb - vt\n",
#     658     "\n",
#     659     "    if isHit == 1:\n",
#     660     "        if fb > 0:\n",
#     661     "            vt = vt + alpha_rew * pe\n",
#     662     "        elif fb < 0:\n",
#     663     "            vt = vt + alpha_pun * pe \n",
#     664     "    \n",
#     665     "    elif isHit == 0:\n",
#     666     "        pe = np.nan\n",
#     667     "        \n",
#     668     "    return vt, pe"
#     669    ]
#     670   },
#     671   {
#     672    "cell_type": "code",
#     673    "execution_count": 67,
#     674    "id": "cf4247ec-e13f-41c1-9a7f-b6d085e50080",
#     675    "metadata": {},
#     676    "outputs": [],
#     677    "source": [
#     678     "def rescorla_wagner_1t(vt, isHit, fb, param_names, param_values):   \n",
#     679     "    \n",
#     680     "    # set alpha to 1 or get its value if its a free parameter\n",
#     681     "    alpha = 0.1 if 'alpha' not in param_names else param_values[param_names.index('alpha')]\n",
#     682     "    \n",
#     683     "    if isHit == 1:\n",
#     684     "        pe = fb - vt\n",
#     685     "        vt = vt + alpha * pe \n",
#     686     "    \n",
#     687     "    elif isHit == 0:\n",
#     688     "        pe = np.nan\n",
#     689     "        \n",
#     690     "    return vt, pe"
#     691    ]
#     692   },
#     693   {
#     694    "cell_type": "markdown",
#     695    "id": "8d4d09ee-3409-412e-aec9-f6383fb791d1",
#     696    "metadata": {},
#     697    "source": [
#     698     "## Decision function"
#     699    ]
#     700   },
#     701   {
#     702    "cell_type": "code",
#     703    "execution_count": 71,
#     704    "id": "6e708fe5-1473-4238-b15b-3abbd635df83",
#     705    "metadata": {},
#     706    "outputs": [],
#     707    "source": [
#     708     "def my_softmax_1t(vt, trial, param_names, param_values): \n",
#     709     "    \n",
#     710     "    # set beta to 1 or get its value if its a free parameter\n",
#     711     "    # same for press bias pi to 0, and for shrinking press bias pi_t\n",
#     712     "    beta = 1 if 'beta' not in param_names else param_values[param_names.index('beta')]\n",
#     713     "    pi = 0 if 'pi' not in param_names else param_values[param_names.index('pi')]\n",
#     714     "    pi_t = 0 if 'pi_t' not in param_names else param_values[param_names.index('pi_t')]\n",
#     715     "    \n",
#     716     "    # normalise the trial, start at 1 at the new block\n",
#     717     "    norm_trial = (trial-56) if trial>56 else trial\n",
#     718     "    shrink = (56 - norm_trial)/56\n",
#     719     "        \n",
#     720     "    v_no_hit = 0\n",
#     721     "    v_hit = vt + pi + pi_t*shrink\n",
#     722     "    diff = v_no_hit - v_hit\n",
#     723     "    \n",
#     724     "    p_hit = 1 / (1 + np.exp(beta * diff))\n",
#     725     "            \n",
#     726     "    return p_hit"
#     727    ]
#     728   },
#     729   {
#     730    "cell_type": "code",
#     731    "execution_count": null,
#     732    "id": "f0366188-6827-4e52-9b5e-a3bc6f0ebecd",
#     733    "metadata": {},
#     734    "outputs": [],
#     735    "source": []
#     736   }
#     737  ],
#     738  "metadata": {
#     739   "kernelspec": {
#     740    "display_name": "Python 3 (ipykernel)",
#     741    "language": "python",
#     742    "name": "python3"
#     743   },
#     744   "language_info": {
#     745    "codemirror_mode": {
#     746     "name": "ipython",
#     747     "version": 3
#     748    },
#     749    "file_extension": ".py",
#     750    "mimetype": "text/x-python",
#     751    "name": "python",
#     752    "nbconvert_exporter": "python",
#     753    "pygments_lexer": "ipython3",
#     754    "version": "3.8.12"
#     755   }
#     756  },
#     757  "nbformat": 4,
#     758  "nbformat_minor": 5
#     759 }
#
# KeyboardInterrupt:

# %% [markdown]
# ## Model 0 - v0, alpha

# %%
# Model specification
mod_info = {}
mod_info['name'] = 'model0_v0_alpha'
mod_info['value_fct'] = fct.rescorla_wagner_1t
mod_info['dec_fct'] = fct.my_softmax_1t
mod_info['param_names'] = ['v0', 'alpha']

# For fitting
param_lower_bounds = [-5, 0]
param_upper_bounds = [ 5, 1]

# Save
all_users_folder = 'data/all_users/fit/' + mod_info['name'] + '/'
file_name = all_users_folder + 'mod_parameters.pkl'
with open(file_name, 'wb') as f:
    pickle.dump(mod_info, f)

# fit to all users
fct.fit_model_to_data(uniqueIDs, mod_info, param_lower_bounds, param_upper_bounds, all_users_folder)

# %% [markdown]
# ## Model 0 - v0, beta

# %%
# Model specification
mod_info = {}
mod_info['name'] = 'model0_v0_beta'
mod_info['value_fct'] = fct.rescorla_wagner_1t
mod_info['dec_fct'] = fct.my_softmax_1t
mod_info['param_names'] = ['v0', 'beta']

# For fitting
param_lower_bounds = [-2, 0.01]
param_upper_bounds = [ 5,    5]

# Save
all_users_folder = 'data/all_users/fit/' + mod_info['name'] + '/'
file_name = all_users_folder + 'mod_parameters.pkl'
with open(file_name, 'wb') as f:
    pickle.dump(mod_info, f)

# fit to all users
fct.fit_model_to_data(uniqueIDs, mod_info, param_lower_bounds, param_upper_bounds, all_users_folder)

# %% [markdown]
# ## Model 0 - v0, alpha, beta

# %%
# Model specification
mod_info = {}
mod_info['name'] = 'model0_v0_alpha_beta'
mod_info['value_fct'] = fct.rescorla_wagner_1t
mod_info['dec_fct'] = fct.my_softmax_1t
mod_info['param_names'] = ['v0', 'alpha', 'beta']

# For fitting
param_lower_bounds = [-5,  0, 0.01]
param_upper_bounds = [ 5,  1,    3]

# Save
all_users_folder = 'data/all_users/fit/' + mod_info['name'] + '/'
file_name = all_users_folder + 'mod_parameters.pkl'
with open(file_name, 'wb') as f:
    pickle.dump(mod_info, f)

# fit to all users
fct.fit_model_to_data(uniqueIDs, mod_info, param_lower_bounds, param_upper_bounds, all_users_folder)

# %% [markdown]
# ## Model 1 - v0, alpha, beta, pi

# %%
# Model specification
mod_info = {}
mod_info['name'] = 'model1_v0_alpha_beta_pi'
mod_info['value_fct'] = fct.rescorla_wagner_1t
mod_info['dec_fct'] = fct.my_softmax_1t
mod_info['param_names'] = ['v0', 'alpha', 'beta', 'pi']

# For fitting
param_lower_bounds = [-2,  0, 0.01, -2]
param_upper_bounds = [ 2,  1,    3,  2]

# Save
all_users_folder = 'data/all_users/fit/' + mod_info['name'] + '/'
file_name = all_users_folder + 'mod_parameters.pkl'
with open(file_name, 'wb') as f:
    pickle.dump(mod_info, f)

# fit to all users
fct.fit_model_to_data(uniqueIDs, mod_info, param_lower_bounds, param_upper_bounds, all_users_folder)

# %% [markdown]
# ## Model 1 - alpha, beta, pi

# %%
# Model specification
mod_info = {}
mod_info['name'] = 'model1_alpha_beta_pi'
mod_info['value_fct'] = fct.rescorla_wagner_1t
mod_info['dec_fct'] = fct.my_softmax_1t
mod_info['param_names'] = ['alpha', 'beta', 'pi']

# For fitting
param_lower_bounds = [0, 0.01, -2]
param_upper_bounds = [1,    2,  2]

# Save
all_users_folder = 'data/all_users/fit/' + mod_info['name'] + '/'
file_name = all_users_folder + 'mod_parameters.pkl'
with open(file_name, 'wb') as f:
    pickle.dump(mod_info, f)

# fit to all users
fct.fit_model_to_data(uniqueIDs, mod_info, param_lower_bounds, param_upper_bounds, all_users_folder)

# %% [markdown]
# ## Model 2 - alpha, beta, pi_t

# %%
# Model specification
mod_info = {}
mod_info['name'] = 'model2_alpha_beta_pi_t'
mod_info['value_fct'] = fct.rescorla_wagner_1t
mod_info['dec_fct'] = fct.my_softmax_1t
mod_info['param_names'] = ['alpha', 'beta', 'pi_t']

# For fitting
param_lower_bounds = [0, 0.01, -2]
param_upper_bounds = [1,    2,  2]

# Save
all_users_folder = 'data/all_users/fit/' + mod_info['name'] + '/'
file_name = all_users_folder + 'mod_parameters.pkl'
with open(file_name, 'wb') as f:
    pickle.dump(mod_info, f)

# fit to all users
fct.fit_model_to_data(uniqueIDs, mod_info, param_lower_bounds, param_upper_bounds, all_users_folder)

# %% [markdown]
# ## Model 2 - v0, alpha, beta, pi_t

# %%
# Model specification
mod_info = {}
mod_info['name'] = 'model2_v0_alpha_beta_pi_t'
mod_info['value_fct'] = fct.rescorla_wagner_1t
mod_info['dec_fct'] = fct.my_softmax_1t
mod_info['param_names'] = ['v0', 'alpha', 'beta', 'pi_t']

# For fitting
param_lower_bounds = [-3, 0, 0.01, -2]
param_upper_bounds = [ 3, 1,    2,  2]

# Save
all_users_folder = 'data/all_users/fit/' + mod_info['name'] + '/'
file_name = all_users_folder + 'mod_parameters.pkl'
with open(file_name, 'wb') as f:
    pickle.dump(mod_info, f)

# fit to all users
fct.fit_model_to_data(uniqueIDs, mod_info, param_lower_bounds, param_upper_bounds, all_users_folder)

# %% [markdown]
# ## Model 3 - alpha_rew, alpha_pun

# %%
# Model specification
mod_info = {}
mod_info['name'] = 'model3_2alpha'
mod_info['value_fct'] = fct.rescorla_wagner_2LR_1t
mod_info['dec_fct'] = fct.my_softmax_1t
mod_info['param_names'] = ['alpha_rew', 'alpha_pun']

# For fitting
param_lower_bounds = [0, 0]
param_upper_bounds = [1, 1]

# Save
all_users_folder = 'data/all_users/fit/' + mod_info['name'] + '/'
file_name = all_users_folder + 'mod_parameters.pkl'
with open(file_name, 'wb') as f:
    pickle.dump(mod_info, f)

# fit to all users
fct.fit_model_to_data(uniqueIDs, mod_info, param_lower_bounds, param_upper_bounds, all_users_folder)

# %% [markdown]
# ## Model 3 - alpha_rew, alpha_pun, beta

# %%
# Model specification
mod_info = {}
mod_info['name'] = 'model3_2alpha_beta'
mod_info['value_fct'] = fct.rescorla_wagner_2LR_1t
mod_info['dec_fct'] = fct.my_softmax_1t
mod_info['param_names'] = ['alpha_rew', 'alpha_pun', 'beta']

# For fitting
param_lower_bounds = [0, 0, 0.01]
param_upper_bounds = [1, 1, 2]

# Save
all_users_folder = 'data/all_users/fit/' + mod_info['name'] + '/'
file_name = all_users_folder + 'mod_parameters.pkl'
with open(file_name, 'wb') as f:
    pickle.dump(mod_info, f)

# fit to all users
fct.fit_model_to_data(uniqueIDs, mod_info, param_lower_bounds, param_upper_bounds, all_users_folder)

# %% [markdown]
# ## Model 3 - alpha_rew, alpha_pun, beta, pi_t

# %%
# Model specification
mod_info = {}
mod_info['name'] = 'model3_2alpha_beta_pi_t'
mod_info['value_fct'] = fct.rescorla_wagner_2LR_1t
mod_info['dec_fct'] = fct.my_softmax_1t
mod_info['param_names'] = ['alpha_rew', 'alpha_pun', 'beta', 'pi_t']

# For fitting
param_lower_bounds = [0, 0, 0.1, -2]
param_upper_bounds = [1, 1, 1.5,  2]

# Save
all_users_folder = 'data/all_users/fit/' + mod_info['name'] + '/'
file_name = all_users_folder + 'mod_parameters.pkl'
with open(file_name, 'wb') as f:
    pickle.dump(mod_info, f)

# fit to all users
fct.fit_model_to_data(uniqueIDs, mod_info, param_lower_bounds, param_upper_bounds, all_users_folder)

# %% [markdown]
# ## Model 3 - v0, alpha_rew, alpha_pun, beta, pi_t

# %%
# Model specification
mod_info = {}
mod_info['name'] = 'model3_v0_2alpha_beta_pi_t'
mod_info['value_fct'] = fct.rescorla_wagner_2LR_1t
mod_info['dec_fct'] = fct.my_softmax_1t
mod_info['param_names'] = ['v0', 'alpha_rew', 'alpha_pun', 'beta', 'pi_t']

# For fitting
param_lower_bounds = [-2, 0, 0, 0.1, -2]
param_upper_bounds = [ 2, 1, 1, 1.5,  2]

# Save
all_users_folder = 'data/all_users/fit/' + mod_info['name'] + '/'
file_name = all_users_folder + 'mod_parameters.pkl'
with open(file_name, 'wb') as f:
    pickle.dump(mod_info, f)

# fit to all users
fct.fit_model_to_data(uniqueIDs, mod_info, param_lower_bounds, param_upper_bounds, all_users_folder)

# %% [markdown]
# ## Model 3 - v0, alpha_rew, alpha_pun, beta

# %%
# Model specification
mod_info = {}
mod_info['name'] = 'model3_v0_2alpha_beta'
mod_info['value_fct'] = fct.rescorla_wagner_2LR_1t
mod_info['dec_fct'] = fct.my_softmax_1t
mod_info['param_names'] = ['v0', 'alpha_rew', 'alpha_pun', 'beta']

# For fitting
param_lower_bounds = [-2, 0, 0, 0.1]
param_upper_bounds = [ 2, 1, 1, 1.5]

# Save
all_users_folder = 'data/all_users/fit/' + mod_info['name'] + '/'
file_name = all_users_folder + 'mod_parameters.pkl'
with open(file_name, 'wb') as f:
    pickle.dump(mod_info, f)

# fit to all users
fct.fit_model_to_data(uniqueIDs, mod_info, param_lower_bounds, param_upper_bounds, all_users_folder)
