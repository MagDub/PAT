# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ptitprince as pt # rainplot
import pickle
import ipynb.fs.defs.functions as fct
from scipy import stats
import pandas as pd

# %%
all_users_folder = 'data/all_users/'

# %%
# Load exclusions
#all_users_folder = 'data/all_users/mod1/'
#file_name = all_users_folder+'mod_exclusions.pkl'
#with open(file_name, "rb") as fp:   
#    exclusions = pickle.load(fp)
    
# Remove excluded
#data_mod1 = data_mod1[~data_mod1['ID'].isin(exclusions)] # rm exclusions

# %% [markdown]
# # Model 0

# %%
dfstats = data_mod_num.describe()
print(dfstats)
# Out:
#                ID         nLL  Ntrials  Nparams         alpha          beta
# count  170.000000  170.000000    170.0    170.0  1.700000e+02  1.700000e+02
# mean   215.917647   53.572055    112.0      2.0  1.612710e-01  3.263653e+00
# std    134.731046   15.307549      0.0      0.0  1.942286e-01  2.265063e+00
# min      1.000000    4.558813    112.0      2.0  3.737686e-09  6.189887e-09
# 25%    103.250000   42.734044    112.0      2.0  2.771646e-02  9.854086e-01
# 50%    201.500000   55.430628    112.0      2.0  8.720438e-02  2.872303e+00
# 75%    326.750000   64.995898    112.0      2.0  2.146990e-01  6.000000e+00
# max    471.000000   77.632484    112.0      2.0  1.000000e+00  6.000000e+00

# %%
# Plot model parameters
model_folder = all_users_folder + 'mod0/'
data_mod = pd.read_pickle(model_folder+'mod_param_fits.pkl')
mod_info = pd.read_pickle(model_folder+'mod_parameters.pkl')
fct.plot_model_parameters(data_mod, mod_info['param_names'])

data_mod_num = data_mod.apply(pd.to_numeric)
data_mod_num.drop('ID', axis=1).describe()

# Plot model predictions and behaviour
ev_per_trial = pd.read_pickle(all_users_folder + 'mod0/mod_ev_per_trial.pkl');
p_hit_per_trial = pd.read_pickle(all_users_folder + 'mod0/mod_p_hit_per_trial.pkl');

fct.fig_modelpred_on_behav(ev_per_trial, p_hit_per_trial, all_users_folder)

# %% [markdown]
# # Model 1

# %%
# Plot model parameters
model_folder = all_users_folder + 'mod1/'
data_mod = pd.read_pickle(model_folder+'mod_param_fits.pkl')
mod_info = pd.read_pickle(model_folder+'mod_parameters.pkl')
fct.plot_model_parameters(data_mod, mod_info['param_names'])

data_mod_num = data_mod.apply(pd.to_numeric)
data_mod_num.drop('ID', axis=1).describe()

# Plot model predictions and behaviour
ev_per_trial = pd.read_pickle(all_users_folder + 'mod1/mod_ev_per_trial.pkl');
p_hit_per_trial = pd.read_pickle(all_users_folder + 'mod1/mod_p_hit_per_trial.pkl');

fct.fig_modelpred_on_behav(ev_per_trial, p_hit_per_trial, all_users_folder)

# %% [markdown]
# # Model 2

# %%
# Plot model parameters
model_folder = all_users_folder + 'mod2/'
data_mod = pd.read_pickle(model_folder+'mod_param_fits.pkl')
mod_info = pd.read_pickle(model_folder+'mod_parameters.pkl')
fct.plot_model_parameters(data_mod, mod_info['param_names'])

data_mod_num = data_mod.apply(pd.to_numeric)
data_mod_num.drop('ID', axis=1).describe()

# Plot model predictions and behaviour
ev_per_trial = pd.read_pickle(all_users_folder + 'mod2/mod_ev_per_trial.pkl');
p_hit_per_trial = pd.read_pickle(all_users_folder + 'mod2/mod_p_hit_per_trial.pkl');

fct.fig_modelpred_on_behav(ev_per_trial, p_hit_per_trial, all_users_folder)

# %% [markdown]
# # Model 3

# %%
# Plot model parameters
model_folder = all_users_folder + 'mod3/'
data_mod = pd.read_pickle(model_folder+'mod_param_fits.pkl')
mod_info = pd.read_pickle(model_folder+'mod_parameters.pkl')
fct.plot_model_parameters(data_mod, mod_info['param_names'])

data_mod_num = data_mod.apply(pd.to_numeric)
data_mod_num.drop('ID', axis=1).describe()

# Plot model predictions and behaviour
ev_per_trial = pd.read_pickle(all_users_folder + 'mod3/mod_ev_per_trial.pkl');
p_hit_per_trial = pd.read_pickle(all_users_folder + 'mod3/mod_p_hit_per_trial.pkl');

fct.fig_modelpred_on_behav(ev_per_trial, p_hit_per_trial, all_users_folder)

# %% [markdown]
# # Model 4

# %%
# Plot model parameters
model_folder = all_users_folder + 'mod4/'
data_mod = pd.read_pickle(model_folder+'mod_param_fits.pkl')
mod_info = pd.read_pickle(model_folder+'mod_parameters.pkl')
fct.plot_model_parameters(data_mod, mod_info['param_names'])

# Plot model predictions and behaviour
ev_per_trial = pd.read_pickle(all_users_folder + 'mod4/mod_ev_per_trial.pkl');
p_hit_per_trial = pd.read_pickle(all_users_folder + 'mod4/mod_p_hit_per_trial.pkl');
fct.fig_modelpred_on_behav(ev_per_trial, p_hit_per_trial, all_users_folder)

# Display stats
data_mod_num = data_mod.apply(pd.to_numeric)
data_mod_num.drop('ID', axis=1).describe()
# Out:
#                 nLL  Ntrials  Nparams          v0         alpha        beta  \
# count    170.000000    170.0    170.0  170.000000  1.700000e+02  170.000000
# mean     210.293699    112.0      4.0    0.557582  1.605241e-01    6.301407
# std     2115.300424      0.0      0.0    2.189676  2.012366e-01    6.837104
# min        0.002506    112.0      4.0  -10.000000  3.236413e-16    0.218922
# 25%       36.467287    112.0      4.0    0.008487  2.583764e-02    1.233103
# 50%       50.149388    112.0      4.0    0.107614  1.015397e-01    3.098526
# 75%       60.357730    112.0      4.0    0.555868  1.893893e-01    8.499366
# max    27627.460323    112.0      4.0   10.000000  1.000000e+00   20.000000
#
#                 w
# count  170.000000
# mean     1.999995
# std      0.000056
# min      1.999280
# 25%      2.000000
# 50%      2.000000
# 75%      2.000000
# max      2.000000

# %% [markdown]
# # Model 5

# %%
# Plot model parameters
model_folder = all_users_folder + 'mod5/'
data_mod = pd.read_pickle(model_folder+'mod_param_fits.pkl')
mod_info = pd.read_pickle(model_folder+'mod_parameters.pkl')
fct.plot_model_parameters(data_mod, mod_info['param_names'])

# Plot model predictions and behaviour
ev_per_trial = pd.read_pickle(all_users_folder + 'mod5/mod_ev_per_trial.pkl');
p_hit_per_trial = pd.read_pickle(all_users_folder + 'mod5/mod_p_hit_per_trial.pkl');
fct.fig_modelpred_on_behav(ev_per_trial, p_hit_per_trial, all_users_folder)

# Display stats
data_mod_num = data_mod.apply(pd.to_numeric)
data_mod_num.drop('ID', axis=1).describe()
# Out:
#               nLL  Ntrials  Nparams          v0       alpha_t        beta
# count  170.000000    170.0    170.0  170.000000  1.700000e+02  170.000000
# mean    48.129994    112.0      3.0    1.126063  2.576612e-01    5.022798
# std     15.633077      0.0      0.0    2.792769  2.836487e-01    5.907641
# min      0.011003    112.0      3.0   -6.229934  7.029396e-16    0.256397
# 25%     39.040467    112.0      3.0    0.004788  3.937351e-02    1.018661
# 50%     50.613029    112.0      3.0    0.224768  1.486034e-01    2.044189
# 75%     59.981798    112.0      3.0    1.250255  3.752350e-01    6.907542
# max     76.630577    112.0      3.0   10.000000  1.000000e+00   20.000000

# %% [markdown]
# # Model 6

# %%
# Plot model parameters
model_folder = all_users_folder + 'mod6/'
data_mod = pd.read_pickle(model_folder+'mod_param_fits.pkl')
mod_info = pd.read_pickle(model_folder+'mod_parameters.pkl')
fct.plot_model_parameters(data_mod, mod_info['param_names'])

# Plot model predictions and behaviour
ev_per_trial = pd.read_pickle(all_users_folder + 'mod6/mod_ev_per_trial.pkl');
p_hit_per_trial = pd.read_pickle(all_users_folder + 'mod6/mod_p_hit_per_trial.pkl');
fct.fig_modelpred_on_behav(ev_per_trial, p_hit_per_trial, all_users_folder)

# Display stats
data_mod_num = data_mod.apply(pd.to_numeric)
data_mod_num.drop('ID', axis=1).describe()
# Out:
#               nLL  Ntrials  Nparams          v0   alpha_rew     alpha_pun  \
# count  170.000000    170.0    170.0  170.000000  170.000000  1.700000e+02
# mean    40.817157    112.0      5.0   -0.811439    0.326260  1.901971e-01
# std     17.646533      0.0      0.0    2.119793    0.299747  2.197047e-01
# min      0.032823    112.0      5.0   -5.000000    0.011767  5.524921e-17
# 25%     27.181606    112.0      5.0   -1.797235    0.075665  4.344158e-02
# 50%     41.173627    112.0      5.0   -0.597813    0.220962  1.236422e-01
# 75%     54.622443    112.0      5.0   -0.028999    0.499461  2.339239e-01
# max     73.819007    112.0      5.0    5.000000    1.000000  1.000000e+00
#
#              beta        pi_t
# count  170.000000  170.000000
# mean     3.638114    1.565320
# std      4.472297    1.860161
# min      0.116850   -8.111893
# 25%      0.866242    0.594922
# 50%      1.674670    1.211436
# 75%      4.092546    2.464337
# max     15.000000    9.025670

# %% [markdown]
# # Model 7

# %%
# Plot model parameters
model_folder = all_users_folder + 'mod7/'
data_mod = pd.read_pickle(model_folder+'mod_param_fits.pkl')
mod_info = pd.read_pickle(model_folder+'mod_parameters.pkl')
fct.plot_model_parameters(data_mod, mod_info['param_names'])

# Plot model predictions and behaviour
ev_per_trial = pd.read_pickle(all_users_folder + 'mod7/mod_ev_per_trial.pkl');
p_hit_per_trial = pd.read_pickle(all_users_folder + 'mod7/mod_p_hit_per_trial.pkl');
fct.fig_modelpred_on_behav(ev_per_trial, p_hit_per_trial, all_users_folder)

# Display stats
data_mod_num = data_mod.apply(pd.to_numeric)
data_mod_num.drop('ID', axis=1).describe()
# Out:
#               nLL  Ntrials  Nparams          v0         alpha        beta  \
# count  170.000000    170.0    170.0  170.000000  1.700000e+02  170.000000
# mean    42.594091    112.0      5.0   -1.004897  2.278655e-01    4.054441
# std     17.042346      0.0      0.0    2.249767  2.173880e-01    4.818474
# min      0.046058    112.0      5.0   -5.000000  4.195385e-10    0.142857
# 25%     29.059720    112.0      5.0   -2.208996  6.563715e-02    0.725288
# 50%     44.059158    112.0      5.0   -0.689281  1.648685e-01    1.897039
# 75%     55.545362    112.0      5.0   -0.009931  3.106527e-01    4.744122
# max     75.053899    112.0      5.0    5.000000  1.000000e+00   15.000000
#
#                   w        pi_t
# count  1.700000e+02  170.000000
# mean   2.000000e+00    2.035117
# std    4.167424e-10    2.296693
# min    2.000000e+00   -6.020572
# 25%    2.000000e+00    0.464794
# 50%    2.000000e+00    1.396337
# 75%    2.000000e+00    3.458667
# max    2.000000e+00   10.000000

# %% [markdown]
# # Model 8

# %%
# Plot model parameters
model_folder = all_users_folder + 'mod8/'
data_mod = pd.read_pickle(model_folder+'mod_param_fits.pkl')
mod_info = pd.read_pickle(model_folder+'mod_parameters.pkl')
fct.plot_model_parameters(data_mod, mod_info['param_names'])

# Plot model predictions and behaviour
ev_per_trial = pd.read_pickle(all_users_folder + 'mod8/mod_ev_per_trial.pkl');
p_hit_per_trial = pd.read_pickle(all_users_folder + 'mod8/mod_p_hit_per_trial.pkl');
fct.fig_modelpred_on_behav(ev_per_trial, p_hit_per_trial, all_users_folder)

# Display stats
data_mod_num = data_mod.apply(pd.to_numeric)
data_mod_num.drop('ID', axis=1).describe()
# Out:
#               nLL  Ntrials  Nparams          v0       alpha_t        beta  \
# count  170.000000    170.0    170.0  170.000000  1.700000e+02  170.000000
# mean    43.112595    112.0      4.0   -0.433812  3.693285e-01    2.905163
# std     17.275286      0.0      0.0    2.690004  3.089058e-01    3.590424
# min      0.023587    112.0      4.0   -5.000000  3.737294e-09    0.126756
# 25%     29.198946    112.0      4.0   -1.934664  1.123177e-01    0.731407
# 50%     44.649720    112.0      4.0   -0.437949  2.768966e-01    1.421967
# 75%     56.115657    112.0      4.0    0.568096  5.592746e-01    3.640145
# max     76.363137    112.0      4.0    5.000000  1.000000e+00   15.000000
#
#              pi_t
# count  170.000000
# mean     1.922833
# std      2.189767
# min    -10.000000
# 25%      0.586220
# 50%      1.571342
# 75%      2.978762
# max      7.902753

# %% [markdown]
# # Model 9

# %%
# Plot model parameters
model_folder = all_users_folder + 'mod9/'
data_mod = pd.read_pickle(model_folder+'mod_param_fits.pkl')
mod_info = pd.read_pickle(model_folder+'mod_parameters.pkl')
fct.plot_model_parameters(data_mod, mod_info['param_names'])

# Plot model predictions and behaviour
ev_per_trial = pd.read_pickle(all_users_folder + 'mod9/mod_ev_per_trial.pkl');
p_hit_per_trial = pd.read_pickle(all_users_folder + 'mod9/mod_p_hit_per_trial.pkl');
fct.fig_modelpred_on_behav(ev_per_trial, p_hit_per_trial, all_users_folder)

# Display stats
data_mod_num = data_mod.apply(pd.to_numeric)
data_mod_num.drop('ID', axis=1).describe()
# Out:
#               nLL  Ntrials  Nparams          v0         alpha        beta  \
# count  170.000000    170.0    170.0  170.000000  1.700000e+02  170.000000
# mean    42.820074    112.0      4.0   -1.136708  2.329046e-01    3.190968
# std     17.163590      0.0      0.0    2.270186  2.161961e-01    4.041805
# min      0.165179    112.0      4.0   -5.000000  7.543369e-16    0.193249
# 25%     29.526945    112.0      4.0   -2.540525  7.495951e-02    0.766067
# 50%     44.380112    112.0      4.0   -0.845239  1.774249e-01    1.471566
# 75%     56.666762    112.0      4.0   -0.044261  3.087981e-01    3.779024
# max     74.744647    112.0      4.0    5.000000  1.000000e+00   15.000000
#
#              pi_t
# count  170.000000
# mean     2.116449
# std      2.005758
# min     -3.153556
# 25%      0.578560
# 50%      1.908078
# 75%      3.296432
# max      9.026061

# %% [markdown]
# # Model 10

# %%
# Plot model parameters
model_folder = all_users_folder + 'mod10/'
data_mod = pd.read_pickle(model_folder+'mod_param_fits.pkl')
mod_info = pd.read_pickle(model_folder+'mod_parameters.pkl')
fct.plot_model_parameters(data_mod, mod_info['param_names'])

# Plot model predictions and behaviour
ev_per_trial = pd.read_pickle(all_users_folder + 'mod10/mod_ev_per_trial.pkl');
p_hit_per_trial = pd.read_pickle(all_users_folder + 'mod10/mod_p_hit_per_trial.pkl');
fct.fig_modelpred_on_behav(ev_per_trial, p_hit_per_trial, all_users_folder)

# Display stats
data_mod_num = data_mod.apply(pd.to_numeric)
data_mod_num.drop('ID', axis=1).describe()
# Out:
#               nLL  Ntrials  Nparams   alpha_rew     alpha_pun        beta  \
# count  170.000000    170.0    170.0  170.000000  1.700000e+02  170.000000
# mean    44.708791    112.0      4.0    0.307749  1.950902e-01    2.446384
# std     16.328629      0.0      0.0    0.261120  1.859066e-01    1.753523
# min      2.437631    112.0      4.0    0.002497  1.938588e-22    0.236190
# 25%     32.778795    112.0      4.0    0.107835  7.713402e-02    0.955473
# 50%     45.496230    112.0      4.0    0.222794  1.420313e-01    1.952280
# 75%     58.008258    112.0      4.0    0.441910  2.478085e-01    4.873909
# max     73.829813    112.0      4.0    1.000000  1.000000e+00    5.000000
#
#              pi_t
# count  170.000000
# mean     0.693490
# std      1.128312
# min     -3.000000
# 25%      0.098322
# 50%      0.456265
# 75%      1.243409
# max      3.000000

# %% [markdown]
# # Model 11

# %%
# Plot model parameters
model_folder = all_users_folder + 'mod11/'
data_mod = pd.read_pickle(model_folder+'mod_param_fits.pkl')
mod_info = pd.read_pickle(model_folder+'mod_parameters.pkl')
fct.plot_model_parameters(data_mod, mod_info['param_names'])

# Plot model predictions and behaviour
ev_per_trial = pd.read_pickle(all_users_folder + 'mod11/mod_ev_per_trial.pkl');
p_hit_per_trial = pd.read_pickle(all_users_folder + 'mod11/mod_p_hit_per_trial.pkl');
fct.fig_modelpred_on_behav(ev_per_trial, p_hit_per_trial, all_users_folder)

# Display stats
data_mod_num = data_mod.apply(pd.to_numeric)
data_mod_num.drop('ID', axis=1).describe()
# Out:
#               nLL  Ntrials  Nparams       alpha_t        beta        pi_t
# count  170.000000    170.0    170.0  1.700000e+02  170.000000  170.000000
# mean    46.622477    112.0      3.0  3.600047e-01    3.187443    1.206060
# std     16.376509      0.0      0.0  3.056142e-01    4.200444    1.728287
# min      0.032375    112.0      3.0  2.031610e-16    0.229019   -4.998216
# 25%     34.196820    112.0      3.0  1.102942e-01    0.769246    0.109220
# 50%     48.105743    112.0      3.0  2.521984e-01    1.464600    0.851057
# 75%     60.018382    112.0      3.0  5.613608e-01    3.171824    2.037281
# max     76.804997    112.0      3.0  1.000000e+00   15.000000    5.000000

# %% [markdown]
# # Model 12

# %%
# Plot model parameters
model_folder = all_users_folder + 'mod12/'
data_mod = pd.read_pickle(model_folder+'mod_param_fits.pkl')
mod_info = pd.read_pickle(model_folder+'mod_parameters.pkl')
fct.plot_model_parameters(data_mod, mod_info['param_names'])

# Plot model predictions and behaviour
ev_per_trial = pd.read_pickle(all_users_folder + 'mod12/mod_ev_per_trial.pkl');
p_hit_per_trial = pd.read_pickle(all_users_folder + 'mod12/mod_p_hit_per_trial.pkl');
fct.fig_modelpred_on_behav(ev_per_trial, p_hit_per_trial, all_users_folder)

# Display stats
data_mod_num = data_mod.apply(pd.to_numeric)
data_mod_num.drop('ID', axis=1).describe()
# Out:
#               nLL  Ntrials  Nparams         v0r         alpha        beta  \
# count  170.000000    170.0    170.0  170.000000  1.700000e+02  170.000000
# mean    42.753250    112.0      4.0   -1.103133  2.272130e-01    3.095964
# std     17.077256      0.0      0.0    2.280013  2.151196e-01    3.796446
# min      0.125878    112.0      4.0   -5.000000  6.284175e-16    0.172163
# 25%     29.518107    112.0      4.0   -2.472856  6.882054e-02    0.805736
# 50%     44.380177    112.0      4.0   -0.865818  1.681474e-01    1.662595
# 75%     56.001221    112.0      4.0   -0.055310  2.953010e-01    3.432138
# max     74.744799    112.0      4.0    5.000000  1.000000e+00   15.000000
#
#              pi_t
# count  170.000000
# mean     2.108115
# std      2.009919
# min     -3.146288
# 25%      0.550978
# 50%      1.863251
# 75%      3.332272
# max      9.026057

# %% [markdown]
# # Model 13

# %%
# Plot model parameters
model_folder = all_users_folder + 'mod13/'
data_mod = pd.read_pickle(model_folder+'mod_param_fits.pkl')
mod_info = pd.read_pickle(model_folder+'mod_parameters.pkl')
fct.plot_model_parameters(data_mod, mod_info['param_names'])

# Plot model predictions and behaviour
ev_per_trial = pd.read_pickle(all_users_folder + 'mod12/mod_ev_per_trial.pkl');
p_hit_per_trial = pd.read_pickle(all_users_folder + 'mod12/mod_p_hit_per_trial.pkl');
fct.fig_modelpred_on_behav(ev_per_trial, p_hit_per_trial, all_users_folder)

# Display stats
data_mod_num = data_mod.apply(pd.to_numeric)
data_mod_num.drop('ID', axis=1).describe()
# Out:
#               nLL  Ntrials  Nparams         v0r         alpha        beta  \
# count  170.000000    170.0    170.0  170.000000  1.700000e+02  170.000000
# mean    45.195813    112.0      4.0   -0.249722  2.512869e-01    3.630921
# std     15.475916      0.0      0.0    2.175120  2.520567e-01    4.195076
# min      7.270617    112.0      4.0   -5.000000  9.703956e-17    0.176728
# 25%     33.659712    112.0      4.0   -1.528798  5.868847e-02    0.871595
# 50%     44.524303    112.0      4.0   -0.150909  1.778084e-01    1.713687
# 75%     56.814035    112.0      4.0    0.804175  3.531008e-01    4.673571
# max     74.237284    112.0      4.0    5.000000  1.000000e+00   15.000000
#
#                pi
# count  170.000000
# mean     0.892159
# std      1.383438
# min     -2.821387
# 25%     -0.036048
# 50%      0.765249
# 75%      1.773040
# max      6.463034

# %% [markdown]
# # Other

# %%
betas = np.arange(0,2,0.2)

p=[]
for i, beta in enumerate(betas):
    vs = np.arange(-10,11,0.5)
    xs = beta*vs  
    p_hit =  np.exp(xs)/(np.exp(xs)+1)
    p.append(plt.plot(vs, p_hit, color='blue', alpha=i/len(betas)))

midle = round(len(betas)/2)
plt.legend([p[1][0], p[midle][0], p[-1][0]], [betas[1], betas[midle], betas[-1]], title='Beta values')
plt.xlabel('Hit value', fontsize=18)
plt.ylabel('Hit probability', fontsize=18)
plt.show()

# %%
# simulate with v0 as free parameter and model without v0
# see difference in onset
# add like a novelty bonus for pressing 

# different alphas for reward and punishment 

# model with a skew in the outcomes (coefficient in front of -5 and 5): between 0 and 2 or so


# compare BICs

# start writing !!!

# %% [markdown]
# ## Compare mod8 and mod9 params

# %%
# Mod8
model_folder = all_users_folder + 'mod8/'
data_mod8 = pd.read_pickle(model_folder+'mod_param_fits.pkl')
mod8_info = pd.read_pickle(model_folder+'mod_parameters.pkl')

# Mod9
model_folder = all_users_folder + 'mod9/'
data_mod9 = pd.read_pickle(model_folder+'mod_param_fits.pkl')
mod9_info = pd.read_pickle(model_folder+'mod_parameters.pkl')

# Specify model in column names
data_mod8.columns = [str(col) + '_mod8' for col in data_mod8.columns]
data_mod9.columns = [str(col) + '_mod9' for col in data_mod9.columns]

# Concat
df = pd.concat([data_mod8, data_mod9], axis=1)
df.drop(['Ntrials_mod8', 'Ntrials_mod9', 'Nparams_mod8' ,'Nparams_mod9', 'ID_mod9'], axis=1, inplace=True)
df.rename(columns={'ID_mod8': 'ID', 'alpha_t_mod8': 'alpha_mod8'}, inplace=True)
df = df.apply(pd.to_numeric)

# Compute BICs
df['BIC_mod8'] = 2*df['nLL_mod8']+4+np.log(112)
df['BIC_mod9'] = 2*df['nLL_mod9']+4+np.log(112)

# describe
print(df.iloc[:,1:6].describe())
print(df.iloc[:,6::].describe())
# Out:
#          nLL_mod8     v0_mod8    alpha_mod8   beta_mod8   pi_t_mod8
# count  170.000000  170.000000  1.700000e+02  170.000000  170.000000
# mean    47.798468   -0.116659  1.811305e-01    3.293070    1.062610
# std     16.920126    2.272556  2.089355e-01    3.500643    1.764987
# min      3.325319   -5.000000  1.264101e-16    0.122773   -6.415641
# 25%     37.156746   -1.234541  3.692270e-02    0.877272    0.192999
# 50%     50.614676   -0.338046  1.023679e-01    1.757615    0.948407
# 75%     61.386058    0.635814  2.453132e-01    4.711434    1.927004
# max     76.705921    5.000000  1.000000e+00   15.000000    6.668164
#          nLL_mod9     v0_mod9    alpha_mod9   beta_mod9   pi_t_mod9  \
# count  170.000000  170.000000  1.700000e+02  170.000000  170.000000
# mean    48.435748   -0.092623  1.139156e-01    3.445958    1.030806
# std     16.706529    2.170045  1.427369e-01    3.950705    2.004097
# min      3.563870   -5.000000  3.737686e-09    0.038199   -7.720410
# ...

# %%
# Convert to wide
dfw = pd.wide_to_long(df, stubnames=['BIC', 'nLL', 'alpha', 'beta', 'pi_t', 'v0'], i="ID", j="model", sep='_', suffix=r'\w+')
param_names = dfw.columns.tolist()
dfw.sort_index(inplace=True)
dfw.reset_index(inplace=True)
dfw.head(10)
# Out:
#    ID model         BIC        nLL     alpha       beta      pi_t        v0
# 0   1  mod8  109.465355  50.373428  0.019962   4.842402  0.188821 -0.455419
# 1   1  mod9  112.163184  51.722343  0.003597  15.000000  0.091153 -0.142368
# 2   3  mod8  110.341565  50.811533  0.012002   8.526228  0.237101 -0.074298
# 3   3  mod9  107.856760  49.569131  0.008376   8.693159  0.249583 -0.102712
# 4   6  mod8  119.192005  55.236753  0.367472   0.843561  0.650046  0.424859
# 5   6  mod9  115.102796  53.192149  0.175788   1.058472  1.031894 -0.736052
# 6   7  mod8  103.996863  47.639182  0.047039   3.056826  0.623029 -0.087755
# 7   7  mod9  107.480419  49.380960  0.030483   2.665146  0.584780  0.008263
# 8   8  mod8   82.940873  37.111187  0.369321   1.678964  1.946131 -2.139896
# 9   8  mod9   84.465036  37.873268  0.182349   1.811809  1.885266 -1.766935

# %%
pal = sns.color_palette(n_colors=1)

# Likelihoods
f, ax1 = plt.subplots(1, 1, figsize=(6, 5))
pt.half_violinplot(ax=ax1, x="model", y="BIC", data=dfw, palette = pal, bw = .2, cut = 0., scale = "area", width = .6, inner = None, orient = 'v')
sns.stripplot(ax=ax1, x="model", y="BIC", data=dfw, palette = pal, edgecolor = "white", size = 4, jitter = 1, zorder = 0, orient = 'v', alpha=.4)
sns.boxplot(ax=ax1, x="model", y="BIC", data=dfw, saturation=1, showfliers=False, width=0.15, boxprops={'zorder': 3, 'facecolor': 'none'})

# Makeup
ax1.set_title('Parameter: ' + "BIC", fontsize=18)
ax1.set_ylabel('Best fit parameter value', fontsize=16)
ax1.set_xticklabels(['mod8', 'mod9'], fontsize=16)
ax1.set_xlabel('')
    
plt.show()

# %%
# Parameters
f, axs = plt.subplots(2, 2, figsize=(2*6, 2*5))
axs = axs.reshape(-1)
plt.subplots_adjust(hspace = 0.3)
pal = sns.color_palette(n_colors=1)
    
for ax, param in zip(axs, param_names[1::]):
    pt.half_violinplot(ax=ax, x="model", y=param, data=dfw, palette = pal, bw = .2, cut = 0., scale = "area", width = .6, inner = None, orient = 'v')
    sns.stripplot(ax=ax, x="model", y=param, data=dfw, palette = pal, edgecolor = "white", size = 4, jitter = 1, zorder = 0, orient = 'v', alpha=.4)
    sns.boxplot(ax=ax, x="model", y=param, data=dfw, saturation=1, showfliers=False, width=0.15, boxprops={'zorder': 3, 'facecolor': 'none'})
    
    # Makeup
    ax.set_title('Parameter: ' + param, fontsize=18)
    ax.set_ylabel('Best fit parameter value', fontsize=16)
    ax.set_xticklabels(['mod8', 'mod9'], fontsize=16)
    ax.set_xlabel('')

axs[0].set_title('Parameter: alpha_t, alpha', fontsize=18)
plt.show()

# %%
# Paired samples t-test
for param in param_names:
    print(param + ':')
    print('means:')
    print('mod8: ', np.mean(df[param + '_mod8']))
    print('mod9: ', np.mean(df[param + '_mod9']))
    print('normality asumption:')
    print('mod8: ', stats.shapiro(df[param + '_mod8']))
    print('mod9: ', stats.shapiro(df[param + '_mod9']))
    print('paired t-test:')
    print(stats.ttest_rel(df[param + '_mod8'], df[param + '_mod9']))
    print('Wilcoxon:')
    print(stats.wilcoxon(df[param + '_mod8'], df[param + '_mod9']))
    print('\n')
# Out:
# BIC:
# means:
# mod8:  104.31543545458298
# mod9:  105.58999482078185
# normality asumption:
# mod8:  ShapiroResult(statistic=0.967164158821106, pvalue=0.00047614341019652784)
# mod9:  ShapiroResult(statistic=0.9658171534538269, pvalue=0.00034189727739430964)
# paired t-test:
# Ttest_relResult(statistic=-3.8856065639237953, pvalue=0.00014633609210649466)
# Wilcoxon:
# WilcoxonResult(statistic=4761.0, pvalue=9.61605197477806e-05)
#
#
# nLL:
# means:
# mod8:  47.79846829164395
# mod9:  48.43574797474338
# normality asumption:
# mod8:  ShapiroResult(statistic=0.9671643376350403, pvalue=0.00047616203664802015)
# mod9:  ShapiroResult(statistic=0.965816855430603, pvalue=0.00034187137498520315)
# paired t-test:
# Ttest_relResult(statistic=-3.8856065639237953, pvalue=0.00014633609210649466)
# Wilcoxon:
# WilcoxonResult(statistic=4761.0, pvalue=9.61605197477806e-05)
#
#
# alpha:
# means:
# mod8:  0.18113047681349354
# mod9:  0.11391557796897692
# normality asumption:
# ...

# %%
param = 'v0'
print('mod8: ', stats.ttest_1samp(df[param + '_mod8'], 0))
print('mod9: ', stats.ttest_1samp(df[param + '_mod9'], 0))
# Out:
# mod8:  Ttest_1sampResult(statistic=-0.6693136632195669, pvalue=0.504208757753263)
# mod9:  Ttest_1sampResult(statistic=-0.5565136129805143, pvalue=0.5785959469927398)

# %% [markdown]
# # T-test likelihood

# %%
nLL_mod8 = df['nLL_mod8']
nLL_mod9 = df['nLL_mod9']

# %%
print('mod8: m =', np.mean(nLL_mod8), 'std =', np.std(nLL_mod8))
print('mod9: m =', np.mean(nLL_mod9), 'std =', np.std(nLL_mod9))
# Out:
# mod8: m = 47.79846829164395 std = 16.870287884171294
# mod9: m = 48.43574797474338 std = 16.657319318421564

# %%
stats.ttest_rel(nLL_mod8, nLL_mod9)
# Out:
# Ttest_relResult(statistic=-3.8856065639237953, pvalue=0.00014633609210649466)

# %%
# check if normality assumption is violated
print(stats.shapiro(nLL_mod8))
print(stats.shapiro(nLL_mod9))
print('Violated!')
# Out:
# ShapiroResult(statistic=0.9671643376350403, pvalue=0.00047616203664802015)
# ShapiroResult(statistic=0.965816855430603, pvalue=0.00034187137498520315)
# Violated!
