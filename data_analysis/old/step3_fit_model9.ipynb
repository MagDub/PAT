# %%
# On terminal: conda activate python38

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import ipynb.fs.defs.functions as fct
import pickle

import warnings
warnings.filterwarnings("error")

# %%
# Load IDs
with open('uniqueIDs.pkl', 'rb') as f:
    uniqueIDs = pickle.load(f)

# %% [markdown]
# # Fit mod9 for each participant

# %%
# Model settings

# Functions
value_fct = fct.rescorla_wagner_2LR_FB_weightRew
dec_fct = fct.my_softmax

# Store everything
mod_info = {}
mod_info['name'] = 'model9'
mod_info['value_fct'] = value_fct.__name__
mod_info['dec_fct'] = dec_fct.__name__
mod_info['param_names'] = ['v0', 'alpha_rew', 'alpha_pun', 'beta', 'w']
#print(mod['value_fct'].__name__)

# save
all_users_folder = 'data/all_users/mod9/'
file_name = all_users_folder+'mod_parameters.pkl'
with open(file_name, 'wb') as f:
    pickle.dump(mod_info, f)

# %%
run_ = True

# Folder
all_users_folder = 'data/all_users/mod9/'
    
if run_:
    
    # Parameter range for initial guess 
    # ['v0', 'alpha_rew', 'alpha_pun', 'beta', 'w']
    param_lower_bound = [-10, 0, 0, 0, 0]
    param_upper_bound = [ 10, 1, 1, 20, 10]

    # Fit
    all_users = {}
    p_hit_per_trial = pd.DataFrame([])
    ev_per_trial = pd.DataFrame([])
    for n_part,ID in enumerate(uniqueIDs): 

        # Get data
        user_folder = 'data/user_' + ID + '/'
        df2_cf = pd.read_pickle(user_folder + 'df2_cf.pkl')
        isHit_all_cues, fbs_all_cues, trialNo_all_cues = fct.extract_hits_fbs(df2_cf)

        # Create a new Model object
        mod = fct.Model(mod_name = mod_info['name'],
                     value_fct = value_fct, 
                     dec_fct = dec_fct, 
                     param_names = mod_info['param_names'])

        # Input data to model
        mod.set_data(ID, fbs_all_cues, isHit_all_cues, trialNo_all_cues)

        # Fit model
        mod.fit(param_lower_bound, param_upper_bound, n_iterations=5)

        # Nested dictionnary user data
        all_users[n_part] = {}
        all_users[n_part]['ID']=mod.ID
        all_users[n_part]['nLL']=mod.nLL
        all_users[n_part]['Ntrials']=mod.Ntrials
        all_users[n_part]['Nparams']=len(mod.param_names)
        for i in range(0,len(mod.param_names)):
            all_users[n_part][mod.param_names[i]]=mod.param_values[i]
        
        # Concatenated model predictions: p hit
        tmp = pd.DataFrame(mod.p_hit).transpose()
        tmp.columns = tmp.columns+1
        tmp = tmp.reset_index().rename(columns={'index': 'Cue'})
        tmp.insert(0,'ID',ID)
        p_hit_per_trial = pd.concat([tmp, p_hit_per_trial], axis=0)
        
        # Concatenated model predictions: EVs
        tmp = pd.DataFrame(mod.v).transpose()
        tmp.columns = tmp.columns+1
        tmp = tmp.reset_index().rename(columns={'index': 'Cue'})
        tmp.insert(0,'ID',ID)
        ev_per_trial = pd.concat([tmp, ev_per_trial], axis=0)
    
    # Save mod LLs and parameter values
    mod_fit = pd.DataFrame(all_users).transpose()
    mod_fit.to_pickle(all_users_folder+'mod_param_fits.pkl')
    
    # Save mod predictions
    p_hit_per_trial = p_hit_per_trial.sort_values(by='ID').reset_index(drop=True)
    p_hit_per_trial.to_pickle(all_users_folder+'mod_p_hit_per_trial.pkl')
    ev_per_trial = ev_per_trial.sort_values(by='ID').reset_index(drop=True)
    ev_per_trial.to_pickle(all_users_folder+'mod_ev_per_trial.pkl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 6>()
#      31 mod.set_data(ID, fbs_all_cues, isHit_all_cues, trialNo_all_cues)
#      33 # Fit model
# ---> 34 mod.fit(param_lower_bound, param_upper_bound, n_iterations=5)
#      36 # Nested dictionnary user data
#      37 all_users[n_part] = {}
#
# File /Volumes/GoogleDrive/Mon Drive/PAT/data_analysis/functions.ipynb:493, in fit(self, param_lower_bound, param_upper_bound, n_iterations, method)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "id": "83916d5c-847d-4008-b2a0-cf1a24e8ab3b",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "import numpy as np\n",
#      11     "import pandas as pd\n",
#      12     "import matplotlib.pyplot as plt\n",
#      13     "from scipy.optimize import minimize\n",
#      14     "import seaborn as sns\n",
#      15     "import ptitprince as pt # rainplot\n",
#      16     "import scipy"
#      17    ]
#      18   },
#      19   {
#      20    "cell_type": "markdown",
#      21    "id": "aec45ccb-f5c6-45bf-bdf9-627bd1e9c037",
#      22    "metadata": {},
#      23    "source": [
#      24     "# Data cleaning"
#      25    ]
#      26   },
#      27   {
#      28    "cell_type": "code",
#      29    "execution_count": 2,
#      30    "id": "ceb57213-a7a8-408d-906a-9fd6def7846e",
#      31    "metadata": {},
#      32    "outputs": [],
#      33    "source": [
#      34     "def extract_hits_fbs(df):\n",
#      35     "    \n",
#      36     "    isHit_all_cues = {}\n",
#      37     "    fbs_all_cues = {}\n",
#      38     "    trialNo_all_cues = {}\n",
#      39     "        \n",
#      40     "    for cue in ['HR', 'LR', 'HP', 'LP']:\n",
#      41     "\n",
#      42     "        # Extract cue data\n",
#      43     "        cue_data_tmp = df[df['Code']==('Cue_' + cue)] \n",
#      44     "\n",
#      45     "        # Create a cue trial column\n",
#      46     "        cue_data_tmp.insert(0, \"CueTrial\", list(range(1,len(cue_data_tmp)+1)))\n",
#      47     "\n",
#      48     "        # Store all in dictionnaries\n",
#      49     "        isHit_all_cues[cue]=cue_data_tmp['isHit'].tolist()\n",
#      50     "        fbs_all_cues[cue]=cue_data_tmp['FBs'].tolist()\n",
#      51     "        trialNo_all_cues[cue]=cue_data_tmp['Trial'].tolist()\n",
#      52     "        \n",
#      53     "    return isHit_all_cues, fbs_all_cues, trialNo_all_cues"
#      54    ]
#      55   },
#      56   {
#      57    "cell_type": "markdown",
#      58    "id": "ddc33407-ae4b-4877-b8bb-8efeacf9965c",
#      59    "metadata": {},
#      60    "source": [
#      61     "# Value functions"
#      62    ]
#      63   },
#      64   {
#      65    "cell_type": "code",
#      66    "execution_count": 3,
#      67    "id": "ce8732e2-395b-4f14-8616-a761b6d7c624",
#      68    "metadata": {},
#      69    "outputs": [],
#      70    "source": [
#      71     "def rescorla_wagner_2LR_FB_weightRew(fbs_all_cues, trialNo_all_cues, param_values, param_names):\n",
#      72     "    \n",
#      73     "    # Free parameters\n",
#      74     "    v0 = param_values[param_names.index('v0')]\n",
#      75     "    w = param_values[param_names.index('w')]\n",
#      76     "    alpha_pos = param_values[param_names.index('alpha_rew')]\n",
#      77     "    alpha_neg = param_values[param_names.index('alpha_pun')]\n",
#      78     "    \n",
#      79     "    # Initialise empty dicitonnary\n",
#      80     "    vt_all_cues = dict.fromkeys(fbs_all_cues.keys())\n",
#      81     "    \n",
#      82     "    # Iterate over cues\n",
#      83     "    for cue, fbs in fbs_all_cues.items():\n",
#      84     "        \n",
#      85     "        # Initialise vector of values\n",
#      86     "        vt = np.empty(len(fbs))\n",
#      87     "        vt.fill(np.nan)\n",
#      88     "        \n",
#      89     "        # Fill in prior\n",
#      90     "        # If want specific prior per cue, check value of cue\n",
#      91     "        vt[0] = v0\n",
#      92     "        \n",
#      93     "        # Iterate to fill in vector\n",
#      94     "        for t in range(1,len(vt)):\n",
#      95     "            \n",
#      96     "           # scale fb\n",
#      97     "            if abs(fbs[t-1]) == 5: \n",
#      98     "                fbs[t-1] = w * fbs[t-1] \n",
#      99     "                \n",
#     100     "            # Compute prediction error\n",
#     101     "            pe = fbs[t-1] - vt[t-1]\n",
#     102     "                        \n",
#     103     "            # Compute new vt and fill in \n",
#     104     "            if fbs[t-1] > 0:\n",
#     105     "                vt[t] = vt[t-1] + alpha_rew * pe\n",
#     106     "            elif fbs[t-1] < 0:\n",
#     107     "                vt[t] = vt[t-1] + alpha_pun * pe\n",
#     108     "            else:\n",
#     109     "                print('error, fb either 0 or nan?')\n",
#     110     "        \n",
#     111     "        vt_all_cues[cue] = vt\n",
#     112     "    \n",
#     113     "    return vt_all_cues"
#     114    ]
#     115   },
#     116   {
#     117    "cell_type": "code",
#     118    "execution_count": 4,
#     119    "id": "42013a82-1712-425b-aa48-f14ca98bd5b8",
#     120    "metadata": {},
#     121    "outputs": [],
#     122    "source": [
#     123     "def rescorla_wagner_2LR_FB(fbs_all_cues, trialNo_all_cues, param_values, param_names):\n",
#     124     "    \n",
#     125     "    # Free parameters\n",
#     126     "    v0 = param_values[param_names.index('v0')]\n",
#     127     "    alpha_rew = param_values[param_names.index('alpha_rew')]\n",
#     128     "    alpha_pun = param_values[param_names.index('alpha_pun')]\n",
#     129     "    \n",
#     130     "    # Initialise empty dicitonnary\n",
#     131     "    vt_all_cues = dict.fromkeys(fbs_all_cues.keys())\n",
#     132     "    \n",
#     133     "    # Iterate over cues\n",
#     134     "    for cue, fbs in fbs_all_cues.items():\n",
#     135     "        \n",
#     136     "        # Initialise vector of values\n",
#     137     "        vt = np.empty(len(fbs))\n",
#     138     "        vt.fill(np.nan)\n",
#     139     "        \n",
#     140     "        # Fill in prior\n",
#     141     "        # If want specific prior per cue, check value of cue\n",
#     142     "        vt[0] = v0\n",
#     143     "        \n",
#     144     "        # Iterate to fill in vector\n",
#     145     "        for t in range(1,len(vt)):\n",
#     146     "            \n",
#     147     "            # Compute prediction error\n",
#     148     "            pe = fbs[t-1] - vt[t-1]\n",
#     149     "                        \n",
#     150     "            # Compute new vt and fill in \n",
#     151     "            if fbs[t-1] > 0:\n",
#     152     "                vt[t] = vt[t-1] + alpha_rew * pe\n",
#     153     "            elif fbs[t-1] < 0:\n",
#     154     "                vt[t] = vt[t-1] + alpha_pun * pe\n",
#     155     "            else:\n",
#     156     "                print('error, fb either 0 or nan?')\n",
#     157     "                \n",
#     158     "        vt_all_cues[cue] = vt\n",
#     159     "    \n",
#     160     "    return vt_all_cues"
#     161    ]
#     162   },
#     163   {
#     164    "cell_type": "code",
#     165    "execution_count": 5,
#     166    "id": "3099f97f-b515-4f23-8653-f306c8fac80f",
#     167    "metadata": {},
#     168    "outputs": [],
#     169    "source": [
#     170     "def rescorla_wagner_2LR_PE(fbs_all_cues, trialNo_all_cues, param_values, param_names):\n",
#     171     "    \n",
#     172     "    # Free parameters\n",
#     173     "    v0 = param_values[param_names.index('v0')]\n",
#     174     "    alpha_pos = param_values[param_names.index('alpha_pos')]\n",
#     175     "    alpha_neg = param_values[param_names.index('alpha_neg')]\n",
#     176     "    \n",
#     177     "    # Initialise empty dicitonnary\n",
#     178     "    vt_all_cues = dict.fromkeys(fbs_all_cues.keys())\n",
#     179     "    \n",
#     180     "    # Iterate over cues\n",
#     181     "    for cue, fbs in fbs_all_cues.items():\n",
#     182     "        \n",
#     183     "        # Initialise vector of values\n",
#     184     "        vt = np.empty(len(fbs))\n",
#     185     "        vt.fill(np.nan)\n",
#     186     "        \n",
#     187     "        # Fill in prior\n",
#     188     "        # If want specific prior per cue, check value of cue\n",
#     189     "        vt[0] = v0\n",
#     190     "        \n",
#     191     "        # Iterate to fill in vector\n",
#     192     "        for t in range(1,len(vt)):\n",
#     193     "            \n",
#     194     "            # Compute prediction error\n",
#     195     "            pe = fbs[t-1] - vt[t-1]\n",
#     196     "                        \n",
#     197     "            # Compute new vt and fill in \n",
#     198     "            if pe >= 0:\n",
#     199     "                vt[t] = vt[t-1] + alpha_pos * pe\n",
#     200     "            elif pe < 0:\n",
#     201     "                vt[t] = vt[t-1] + alpha_neg * pe\n",
#     202     "            else:\n",
#     203     "                print('error')\n",
#     204     "                \n",
#     205     "        vt_all_cues[cue] = vt\n",
#     206     "    \n",
#     207     "    return vt_all_cues"
#     208    ]
#     209   },
#     210   {
#     211    "cell_type": "code",
#     212    "execution_count": 6,
#     213    "id": "70b06904-d4aa-40bf-bb69-b76fb0c73122",
#     214    "metadata": {},
#     215    "outputs": [],
#     216    "source": [
#     217     "def rescorla_wagner_weightRew(fbs_all_cues, trialNo_all_cues, param_values, param_names):\n",
#     218     "    \n",
#     219     "    # Free parameters\n",
#     220     "    v0 = param_values[param_names.index('v0')]\n",
#     221     "    alpha = param_values[param_names.index('alpha')]\n",
#     222     "    w = param_values[param_names.index('w')]\n",
#     223     "    \n",
#     224     "    # Initialise empty dicitonnary\n",
#     225     "    vt_all_cues = dict.fromkeys(fbs_all_cues.keys())\n",
#     226     "    \n",
#     227     "    # Iterate over cues\n",
#     228     "    for cue, fbs in fbs_all_cues.items():\n",
#     229     "        \n",
#     230     "        # Initialise vector of values\n",
#     231     "        vt = np.empty(len(fbs))\n",
#     232     "        vt.fill(np.nan)\n",
#     233     "        \n",
#     234     "        # Fill in prior\n",
#     235     "        # If want specific prior per cue, check value of cue\n",
#     236     "        vt[0] = v0\n",
#     237     "        \n",
#     238     "        # Iterate to fill in vector\n",
#     239     "        for t in range(1,len(vt)):\n",
#     240     "            \n",
#     241     "           # scale fb\n",
#     242     "            if abs(fbs[t-1]) == 5: \n",
#     243     "                fbs[t-1] = w * fbs[t-1] \n",
#     244     "                \n",
#     245     "            # Compute prediction error\n",
#     246     "            pe = fbs[t-1] - vt[t-1]\n",
#     247     "            \n",
#     248     "            # Compute new vt and fill in \n",
#     249     "            vt[t] = vt[t-1] + alpha * pe\n",
#     250     "        \n",
#     251     "        vt_all_cues[cue] = vt\n",
#     252     "    \n",
#     253     "    return vt_all_cues"
#     254    ]
#     255   },
#     256   {
#     257    "cell_type": "code",
#     258    "execution_count": 7,
#     259    "id": "28ff02e9-3a0b-4acf-b1f4-4211012caee7",
#     260    "metadata": {},
#     261    "outputs": [],
#     262    "source": [
#     263     "def rescorla_wagner_noV0(fbs_all_cues, trialNo_all_cues, param_values, param_names):\n",
#     264     "    \n",
#     265     "    # Fixed parameter\n",
#     266     "    v0 = 0\n",
#     267     "        \n",
#     268     "    # Free parameters\n",
#     269     "    alpha = param_values[param_names.index('alpha')]\n",
#     270     "    \n",
#     271     "    # Initialise empty dicitonnary\n",
#     272     "    vt_all_cues = dict.fromkeys(fbs_all_cues.keys())\n",
#     273     "    \n",
#     274     "    # Iterate over cues\n",
#     275     "    for cue, fbs in fbs_all_cues.items():\n",
#     276     "        \n",
#     277     "        # Initialise vector of values\n",
#     278     "        vt = np.empty(len(fbs))\n",
#     279     "        vt.fill(np.nan)\n",
#     280     "        \n",
#     281     "        # Fill in prior\n",
#     282     "        # If want specific prior per cue, check value of cue\n",
#     283     "        vt[0] = v0\n",
#     284     "        \n",
#     285     "        # Iterate to fill in vector\n",
#     286     "        for t in range(1,len(vt)):\n",
#     287     "            \n",
#     288     "            # Compute prediction error\n",
#     289     "            pe = fbs[t-1] - vt[t-1]\n",
#     290     "            \n",
#     291     "            # Compute new vt and fill in \n",
#     292     "            vt[t] = vt[t-1] + alpha * pe\n",
#     293     "                \n",
#     294     "        vt_all_cues[cue] = vt\n",
#     295     "    \n",
#     296     "    return vt_all_cues"
#     297    ]
#     298   },
#     299   {
#     300    "cell_type": "code",
#     301    "execution_count": 8,
#     302    "id": "c71f01eb-157c-49b9-b54c-f8170dd88589",
#     303    "metadata": {},
#     304    "outputs": [],
#     305    "source": [
#     306     "def rescorla_wagner_press_bias(fbs_all_cues, trialNo_all_cues, param_values, param_names):\n",
#     307     "    \n",
#     308     "    # Free parameters\n",
#     309     "    v0 = param_values[param_names.index('v0')]\n",
#     310     "    alpha = param_values[param_names.index('alpha')]\n",
#     311     "    pi = param_values[param_names.index('pi')]\n",
#     312     "    \n",
#     313     "    # Initialise empty dicitonnary\n",
#     314     "    vt_all_cues = dict.fromkeys(fbs_all_cues.keys())\n",
#     315     "    \n",
#     316     "    # Iterate over cues\n",
#     317     "    for cue, fbs in fbs_all_cues.items():\n",
#     318     "        \n",
#     319     "        # Initialise vector of values\n",
#     320     "        vt = np.empty(len(fbs))\n",
#     321     "        vt.fill(np.nan)\n",
#     322     "        \n",
#     323     "        # Fill in prior\n",
#     324     "        # If want specific prior per cue, check value of cue\n",
#     325     "        vt[0] = v0\n",
#     326     "        \n",
#     327     "        # Iterate to fill in vector\n",
#     328     "        for t in range(1,len(vt)):\n",
#     329     "            \n",
#     330     "            # Compute prediction error\n",
#     331     "            pe = fbs[t-1] - vt[t-1]\n",
#     332     "            \n",
#     333     "            # Compute new vt and fill in \n",
#     334     "            vt[t] = vt[t-1] + alpha * pe + pi\n",
#     335     "        \n",
#     336     "        vt_all_cues[cue] = vt\n",
#     337     "    \n",
#     338     "    return vt_all_cues"
#     339    ]
#     340   },
#     341   {
#     342    "cell_type": "code",
#     343    "execution_count": 9,
#     344    "id": "124c395b-9702-49e9-9f5e-3452c63aed49",
#     345    "metadata": {},
#     346    "outputs": [],
#     347    "source": [
#     348     "def rescorla_wagner_shrinking_alpha(fbs_all_cues, trialNo_all_cues, param_values, param_names):\n",
#     349     "    \n",
#     350     "    # Free parameters\n",
#     351     "    v0 = param_values[param_names.index('v0')]\n",
#     352     "    alpha = param_values[param_names.index('alpha')]\n",
#     353     "    alpha_t = param_values[param_names.index('alpha_t')]\n",
#     354     "    \n",
#     355     "    # Number of trials\n",
#     356     "    Ntrials = sum(len(lst) for lst in fbs_all_cues.values())\n",
#     357     "    \n",
#     358     "    # Initialise empty dicitonnary\n",
#     359     "    vt_all_cues = dict.fromkeys(fbs_all_cues.keys())\n",
#     360     "        \n",
#     361     "    # Iterate over cues\n",
#     362     "    for cue, fbs in fbs_all_cues.items():\n",
#     363     "        \n",
#     364     "        trials = trialNo_all_cues[cue]\n",
#     365     "        \n",
#     366     "        # Initialise vector of values\n",
#     367     "        vt = np.empty(len(fbs))\n",
#     368     "        vt.fill(np.nan)\n",
#     369     "        \n",
#     370     "        # Fill in prior\n",
#     371     "        # If want specific prior per cue, check value of cue\n",
#     372     "        vt[0] = v0\n",
#     373     "                \n",
#     374     "        # Iterate to fill in vector\n",
#     375     "        for t in range(1,len(trials)):\n",
#     376     "            \n",
#     377     "            trial = trials[t-1]\n",
#     378     "                        \n",
#     379     "            # Compute prediction error\n",
#     380     "            pe = fbs[t-1] - vt[t-1]\n",
#     381     "                        \n",
#     382     "            # Compute new vt and fill in \n",
#     383     "            shrink = (Ntrials - trial)/Ntrials\n",
#     384     "            vt[t] = vt[t-1] + (alpha + alpha_t * shrink)  * pe\n",
#     385     "        \n",
#     386     "        vt_all_cues[cue] = vt\n",
#     387     "    \n",
#     388     "    return vt_all_cues"
#     389    ]
#     390   },
#     391   {
#     392    "cell_type": "code",
#     393    "execution_count": 10,
#     394    "id": "4de01ffc-f48f-4034-bc84-457da34ccc6c",
#     395    "metadata": {},
#     396    "outputs": [],
#     397    "source": [
#     398     "def rescorla_wagner(fbs_all_cues, trialNo_all_cues, param_values, param_names):\n",
#     399     "    \n",
#     400     "    # Free parameters\n",
#     401     "    v0 = param_values[param_names.index('v0')]\n",
#     402     "    alpha = param_values[param_names.index('alpha')]\n",
#     403     "    \n",
#     404     "    # Initialise empty dicitonnary\n",
#     405     "    vt_all_cues = dict.fromkeys(fbs_all_cues.keys())\n",
#     406     "    \n",
#     407     "    # Iterate over cues\n",
#     408     "    for cue, fbs in fbs_all_cues.items():\n",
#     409     "        \n",
#     410     "        # Initialise vector of values\n",
#     411     "        vt = np.empty(len(fbs))\n",
#     412     "        vt.fill(np.nan)\n",
#     413     "        \n",
#     414     "        # Fill in prior\n",
#     415     "        # If want specific prior per cue, check value of cue\n",
#     416     "        vt[0] = v0\n",
#     417     "        \n",
#     418     "        # Iterate to fill in vector\n",
#     419     "        for t in range(1,len(vt)):\n",
#     420     "            \n",
#     421     "            # Compute prediction error\n",
#     422     "            pe = fbs[t-1] - vt[t-1]\n",
#     423     "            \n",
#     424     "            # Compute new vt and fill in \n",
#     425     "            vt[t] = vt[t-1] + alpha * pe\n",
#     426     "        \n",
#     427     "        vt_all_cues[cue] = vt\n",
#     428     "    \n",
#     429     "    return vt_all_cues"
#     430    ]
#     431   },
#     432   {
#     433    "cell_type": "markdown",
#     434    "id": "ada59fb5-5434-4a87-b449-2db647a76606",
#     435    "metadata": {},
#     436    "source": [
#     437     "# Decision functions"
#     438    ]
#     439   },
#     440   {
#     441    "cell_type": "code",
#     442    "execution_count": 11,
#     443    "id": "b5c942e6-0f1c-43ef-a1dc-92bf979146d1",
#     444    "metadata": {},
#     445    "outputs": [],
#     446    "source": [
#     447     "def my_softmax_press_bias(vt_all_cues, param_values, param_names):\n",
#     448     "    \n",
#     449     "    # Free parameters\n",
#     450     "    beta = param_values[param_names.index('beta')]\n",
#     451     "    pi = param_values[param_names.index('pi')]\n",
#     452     "    \n",
#     453     "    # Initialise empty dicitonnary\n",
#     454     "    p_hit_all_cues = dict.fromkeys(vt_all_cues.keys())\n",
#     455     "    \n",
#     456     "    # Iterate over cues\n",
#     457     "    for cue, vt in vt_all_cues.items():\n",
#     458     "                \n",
#     459     "        x = beta * (vt + pi)\n",
#     460     "        \n",
#     461     "        try:\n",
#     462     "            p_hit =  np.exp(x)/(np.exp(x)+1)\n",
#     463     "        except RuntimeWarning:\n",
#     464     "            # to avoid overflow errors\n",
#     465     "            expon_bound = 700\n",
#     466     "            p_hit = [1 if el>expon_bound else (np.exp(el)/(np.exp(el)+1)) for el in x]\n",
#     467     "            \n",
#     468     "        p_hit_all_cues[cue] = p_hit\n",
#     469     "    \n",
#     470     "    return p_hit_all_cues"
#     471    ]
#     472   },
#     473   {
#     474    "cell_type": "code",
#     475    "execution_count": 12,
#     476    "id": "fcba95aa-2edd-4525-a7db-f35785054118",
#     477    "metadata": {},
#     478    "outputs": [],
#     479    "source": [
#     480     "def my_softmax(vt_all_cues, param_values, param_names):\n",
#     481     "    \n",
#     482     "    # Free parameters\n",
#     483     "    beta = param_values[param_names.index('beta')]\n",
#     484     "    \n",
#     485     "    # Initialise empty dicitonnary\n",
#     486     "    p_hit_all_cues = dict.fromkeys(vt_all_cues.keys())\n",
#     487     "    \n",
#     488     "    # Iterate over cuesss\n",
#     489     "    for cue, vt in vt_all_cues.items():\n",
#     490     "                \n",
#     491     "        x = beta*vt\n",
#     492     "        \n",
# --> 493     "        try:\n",
#     494     "            p_hit =  np.exp(x)/(np.exp(x)+1)\n",
#     495     "            \n",
#     496     "        except RuntimeWarning:\n",
#     497     "            # to avoid overflow errors\n",
#     498     "            expon_bound = 700\n",
#     499     "            p_hit = [1 if el>expon_bound else (np.exp(el)/(np.exp(el)+1)) for el in x]\n",
#     500     "            \n",
#     501     "        p_hit_all_cues[cue] = p_hit\n",
#     502     "    \n",
#     503     "    return p_hit_all_cues"
#     504    ]
#     505   },
#     506   {
#     507    "cell_type": "code",
#     508    "execution_count": 13,
#     509    "id": "738824ad-68fd-463a-894b-803317e22398",
#     510    "metadata": {},
#     511    "outputs": [],
#     512    "source": [
#     513     "def my_softmax_scipy(vt_all_cues, param_values, param_names):\n",
#     514     "    \n",
#     515     "    # Free parameters\n",
#     516     "    beta = param_values[param_names.index('beta')]\n",
#     517     "    \n",
#     518     "    # Initialise empty dictionnary\n",
#     519     "    p_hit_all_cues = dict.fromkeys(vt_all_cues.keys())\n",
#     520     "\n",
#     521     "    for cue, vts in vt_all_cues.items():\n",
#     522     "        p_hit = []\n",
#     523     "        for vt in vts:\n",
#     524     "            Q_hit = vt * beta\n",
#     525     "            Q_miss = 0\n",
#     526     "            probs = scipy.special.softmax([Q_hit, Q_miss])\n",
#     527     "            p_hit.append(probs[0])\n",
#     528     "\n",
#     529     "        p_hit_all_cues[cue] = np.array(p_hit)\n",
#     530     "    \n",
#     531     "    return p_hit_all_cues"
#     532    ]
#     533   },
#     534   {
#     535    "cell_type": "markdown",
#     536    "id": "1dd00c6b-e18d-4c1e-ba95-e08c07f3e3c1",
#     537    "metadata": {},
#     538    "source": [
#     539     "# Model"
#     540    ]
#     541   },
#     542   {
#     543    "cell_type": "code",
#     544    "execution_count": 14,
#     545    "id": "e7dc1cf5-494f-49bb-99da-1dc978befa28",
#     546    "metadata": {},
#     547    "outputs": [],
#     548    "source": [
#     549     "class Model:\n",
#     550     "    \n",
#     551     "    def __init__(self, mod_name, value_fct, dec_fct, param_names):\n",
#     552     "        self.value_fct = value_fct\n",
#     553     "        self.dec_fct = dec_fct\n",
#     554     "        self.param_names = param_names\n",
#     555     "        self.mod_name = mod_name\n",
#     556     "        self.param_values = []\n",
#     557     "        self.values = []\n",
#     558     "        self.p_hit = []\n",
#     559     "        self.cue_nLLs = []\n",
#     560     "        self.total_cue_nLL = []\n",
#     561     "        self.fbs_all_cues = []\n",
#     562     "        self.isHit_all_cues = []\n",
#     563     "        self.nLL = []\n",
#     564     "        self.ID = []  \n",
#     565     "        self.Ntrials = []  \n",
#     566     "    \n",
#     567     "    def set_param_values(self, param_values):\n",
#     568     "        self.param_values = param_values\n",
#     569     "            \n",
#     570     "    def set_data(self, ID, fbs_all_cues, isHit_all_cues, trialNo_all_cues):\n",
#     571     "        self.ID = ID\n",
#     572     "        self.fbs_all_cues = fbs_all_cues\n",
#     573     "        self.isHit_all_cues = isHit_all_cues\n",
#     574     "        self.trialNo_all_cues = trialNo_all_cues\n",
#     575     "            \n",
#     576     "    def compute_ll_per_cue(self, p_hit_all_cues, isHit_all_cues):\n",
#     577     "        \n",
#     578     "        # Initialise empty dicitonnary\n",
#     579     "        nLLs_all_cues = dict.fromkeys(p_hit_all_cues.keys())\n",
#     580     "        total_nLL_all_cues = dict.fromkeys(p_hit_all_cues.keys())\n",
#     581     "        Ntrials_per_cue = dict.fromkeys(p_hit_all_cues.keys())\n",
#     582     "        \n",
#     583     "        # Iterate over cues\n",
#     584     "        for cue, p_hit in p_hit_all_cues.items():\n",
#     585     "            isHit = isHit_all_cues[cue]\n",
#     586     "            # compute likelihoods of choices\n",
#     587     "            ll_choice = []\n",
#     588     "            almost_zero = np.finfo(float).tiny\n",
#     589     "            for ind, hit in enumerate(isHit):\n",
#     590     "                if hit==1:\n",
#     591     "                    p_ =  p_hit[ind]\n",
#     592     "                else:\n",
#     593     "                    p_ =  1-p_hit[ind]\n",
#     594     "                    \n",
#     595     "                ll_choice.append(almost_zero if p_<almost_zero else p_)\n",
#     596     "                             \n",
#     597     "            nLLs = -np.log(ll_choice)\n",
#     598     "            nLLs_all_cues[cue] = nLLs\n",
#     599     "            total_nLL_all_cues[cue] = sum(nLLs)\n",
#     600     "            Ntrials_per_cue[cue] = len(nLLs)\n",
#     601     "            \n",
#     602     "        return total_nLL_all_cues, nLLs_all_cues, Ntrials_per_cue\n",
#     603     "    \n",
#     604     "    def fit(self, param_lower_bound, param_upper_bound, n_iterations, method='Powell'):\n",
#     605     "        \n",
#     606     "        # compute sequence of parameter bounds\n",
#     607     "        bounds = []\n",
#     608     "        for low, up in zip(param_lower_bound,param_upper_bound):\n",
#     609     "            bounds.append([low,up])\n",
#     610     "        \n",
#     611     "        # init\n",
#     612     "        mat_min_nLL=[]\n",
#     613     "        mat_best_params=[]\n",
#     614     "\n",
#     615     "        for i in range(0,n_iterations):\n",
#     616     "\n",
#     617     "            # define the starting point as a random sample from the domain\n",
#     618     "            initial_guess = np.array(param_lower_bound) + np.random.rand(len(param_lower_bound)) * (np.array(param_upper_bound) - np.array(param_lower_bound))\n",
#     619     "\n",
#     620     "            # find the min likelihood \n",
#     621     "            result = minimize(self.compute_nLL, initial_guess, method = method, bounds = bounds, \n",
#     622     "                              options={'xtol': 1e-8, 'disp': False})\n",
#     623     "\n",
#     624     "            # store min_nLL and parameters\n",
#     625     "            mat_min_nLL.append(result.fun)\n",
#     626     "            mat_best_params.append(result.x)\n",
#     627     "\n",
#     628     "        # Find best params\n",
#     629     "        ind = np.argmin(mat_min_nLL)\n",
#     630     "        best_params = mat_best_params[ind]\n",
#     631     "\n",
#     632     "        # Compute best LL and store in mod1\n",
#     633     "        nLL = self.compute_nLL(best_params)   \n",
#     634     "                \n",
#     635     "    \n",
#     636     "    def compute_nLL(self, param_values):\n",
#     637     "        \n",
#     638     "        fbs_all_cues = self.fbs_all_cues\n",
#     639     "        isHit_all_cues = self.isHit_all_cues\n",
#     640     "        trialNo_all_cues = self.trialNo_all_cues\n",
#     641     "        \n",
#     642     "        # set parameter values\n",
#     643     "        self.set_param_values(param_values)\n",
#     644     "\n",
#     645     "        # compute expected values\n",
#     646     "        vt_all_cues = self.value_fct(fbs_all_cues, self.trialNo_all_cues, self.param_values, self.param_names)\n",
#     647     "        \n",
#     648     "        # compute hit probability\n",
#     649     "        p_hit_all_cues  = self.dec_fct(vt_all_cues, self.param_values, self.param_names)\n",
#     650     "        \n",
#     651     "        # compute nLL per cue\n",
#     652     "        total_nLL_all_cues, nLLs_all_cues, Ntrials_per_cue = self.compute_ll_per_cue(p_hit_all_cues, isHit_all_cues)\n",
#     653     "        \n",
#     654     "        # compute total neg LL (sum over cues, i.e. multiply likelihoods)\n",
#     655     "        nLL = sum(total_nLL_all_cues.values())\n",
#     656     "        \n",
#     657     "        # save total number of trials\n",
#     658     "        Ntrials = sum(Ntrials_per_cue.values())\n",
#     659     "        \n",
#     660     "        # Set values\n",
#     661     "        self.v = vt_all_cues\n",
#     662     "        self.p_hit = p_hit_all_cues\n",
#     663     "        self.cue_nLLs = nLLs_all_cues\n",
#     664     "        self.total_cue_nLL = total_nLL_all_cues\n",
#     665     "        self.nLL = nLL\n",
#     666     "        self.Ntrials = Ntrials\n",
#     667     "        \n",
#     668     "        return nLL"
#     669    ]
#     670   },
#     671   {
#     672    "cell_type": "markdown",
#     673    "id": "3878fb07-a01b-475a-92cb-f4186e5b7c67",
#     674    "metadata": {},
#     675    "source": [
#     676     "# Ploting"
#     677    ]
#     678   },
#     679   {
#     680    "cell_type": "code",
#     681    "execution_count": 28,
#     682    "id": "f36fce68-ee9e-4a05-9bfe-b6377fc8b4d8",
#     683    "metadata": {},
#     684    "outputs": [],
#     685    "source": [
#     686     "def plot_model_behaviour_allcues(mod1, window_size, save_fig=False):\n",
#     687     "    \n",
#     688     "    # User folder for running average data\n",
#     689     "    user_folder = 'data/user_' + mod1.ID + '/cue_hit_miss_perc/'\n",
#     690     "    \n",
#     691     "    # Timepoints\n",
#     692     "    N_trials = 28\n",
#     693     "    N_iter = int(N_trials/window_size)\n",
#     694     "    timepoints = ['t'+ str(t+1) for t in range(N_iter)]\n",
#     695     "    xt = (np.arange(len(timepoints))+1)*window_size\n",
#     696     "\n",
#     697     "    fig, axs = plt.subplots(4, 1, figsize=(10,10), facecolor='white')\n",
#     698     "    plt.subplots_adjust(hspace=0.5)\n",
#     699     "\n",
#     700     "    cues = ['HR', 'HP', 'LR', 'LP']\n",
#     701     "\n",
#     702     "    for i,cue in enumerate(cues):\n",
#     703     "\n",
#     704     "        ax = axs[i]\n",
#     705     "\n",
#     706     "        # Extract data for plotting\n",
#     707     "        p_hit_model = mod1.p_hit[cue]\n",
#     708     "        vt_model = mod1.v[cue]\n",
#     709     "        isHit = mod1.isHit_all_cues[cue]\n",
#     710     "        fbs = mod1.fbs_all_cues[cue]\n",
#     711     "        hit_miss_perc = pd.read_pickle(user_folder + 'hit_miss_perc_' + cue + '_window_size_' + str(window_size) + '.pkl')\n",
#     712     "\n",
#     713     "        # Plot fbs\n",
#     714     "        height_fb = 1.13\n",
#     715     "        x = [ind+1 for ind, el in enumerate(fbs) if el == 5]\n",
#     716     "        l_fb_5 = ax.scatter(x, height_fb * np.ones(len(x)), c='green', alpha=0.9)\n",
#     717     "        x = [ind+1 for ind, el in enumerate(fbs) if el == 1]\n",
#     718     "        l_fb_1 = ax.scatter(x, height_fb * np.ones(len(x)), c='green', alpha=0.1)\n",
#     719     "        x = [ind+1 for ind, el in enumerate(fbs) if el == -1]\n",
#     720     "        l_fb_m1 = ax.scatter(x, height_fb * np.ones(len(x)), c='red', alpha=0.1)\n",
#     721     "        x = [ind+1 for ind, el in enumerate(fbs) if el == -5]\n",
#     722     "        l_fb_m5 = ax.scatter(x, height_fb * np.ones(len(x)), c='red', alpha=0.9)\n",
#     723     "\n",
#     724     "        # Plot hits (marker)\n",
#     725     "        height_hit = 1.2\n",
#     726     "        x_hit = [ind+1 for ind, el in enumerate(isHit) if el == 1]\n",
#     727     "        l_hits = ax.scatter(x_hit, height_hit * np.ones(len(x_hit)), c='black', alpha=1, marker='v')\n",
#     728     "\n",
#     729     "        # Plot hit perc (running average)\n",
#     730     "        l_wind_m, = ax.plot(xt, hit_miss_perc.loc['hit'], '.-', color='darkorange', alpha=1)\n",
#     731     "\n",
#     732     "        # Plot probability of hits (from model)\n",
#     733     "        l_p_h_mod, = ax.plot(list(range(1,len(p_hit_model)+1)), p_hit_model)\n",
#     734     "\n",
#     735     "        # Legend\n",
#     736     "        ax.legend([l_wind_m, l_p_h_mod], \n",
#     737     "                  ['Hit running average', \n",
#     738     "                   'Hit model probability (alpha=' + str(round(mod1.param_values[1],2))+\n",
#     739     "                   ', v0='+ str(round(mod1.param_values[0],2))+\n",
#     740     "                   ', beta='+ str(round(mod1.param_values[2],2)) + ')'],\n",
#     741     "                  frameon=False)\n",
#     742     "\n",
#     743     "        # Labels etc \n",
#     744     "        ax.set_ylim([0,1.24])\n",
#     745     "\n",
#     746     "        # Title \n",
#     747     "        ax.set_title(cue)\n",
#     748     "\n",
#     749     "        # Plot vertical grid\n",
#     750     "        ax.grid(axis=\"x\", alpha=0.1)\n",
#     751     "\n",
#     752     "        # Plot horizontal line at 0\n",
#     753     "        ax.plot(np.arange(-1,30), np.zeros(len(np.arange(-1,30))), 'k--', alpha=0.5, linewidth=1.0)\n",
#     754     "\n",
#     755     "        # x-axis (trials)\n",
#     756     "        x_ticks = list(range(1,len(fbs)+1))\n",
#     757     "        ax.set_xlim(x_ticks[0]-1,x_ticks[-1]+1)\n",
#     758     "        ax.set_xticks(x_ticks)\n",
#     759     "        ax.set_xlabel('', fontsize = 18)\n",
#     760     "\n",
#     761     "    \n",
#     762     "    if save_fig:\n",
#     763     "        user_fig = 'data/user_' + mod1.ID + '/behav_' + mod1.mod_name + '.png'\n",
#     764     "        plt.savefig(user_fig)\n",
#     765     "        plt.close() \n",
#     766     "    else:\n",
#     767     "        plt.show()"
#     768    ]
#     769   },
#     770   {
#     771    "cell_type": "code",
#     772    "execution_count": 11,
#     773    "id": "35358520-9aa4-4336-bf96-a7c32c92454b",
#     774    "metadata": {},
#     775    "outputs": [],
#     776    "source": [
#     777     "def plot_model_parameters(data_mod, param_names):\n",
#     778     "    \n",
#     779     "    Nparam = len(param_names)\n",
#     780     "    \n",
#     781     "    if Nparam<=3:\n",
#     782     "        f, axs = plt.subplots(1, Nparam, figsize=(Nparam*6, 5))\n",
#     783     "    elif Nparam==4:\n",
#     784     "        f, axs = plt.subplots(2, 2, figsize=(2*6, 2*5))\n",
#     785     "        axs = axs.reshape(-1)\n",
#     786     "    else:\n",
#     787     "        f, axs = plt.subplots(2, 3, figsize=(3*6, 2*5))\n",
#     788     "        axs = axs.reshape(-1)\n",
#     789     "        \n",
#     790     "    plt.subplots_adjust(hspace = 0.3)\n",
#     791     "        \n",
#     792     "    pal = sns.color_palette(n_colors=1)\n",
#     793     "\n",
#     794     "    for ax, param in zip(axs, param_names):\n",
#     795     "\n",
#     796     "        y = data_mod[param].tolist()\n",
#     797     "\n",
#     798     "        # plot clouds\n",
#     799     "        pt.half_violinplot(ax=ax, x = y, palette = pal, bw = .2, cut = 0., scale = \"area\", width = .6, inner = None, orient = 'h')\n",
#     800     "\n",
#     801     "        # add rain\n",
#     802     "        sns.stripplot(ax=ax, x = y, palette = pal, edgecolor = \"white\", size = 5, jitter = 1, zorder = 0, orient = 'h', alpha=.35)\n",
#     803     "\n",
#     804     "        sns.boxplot(x = y, saturation=1, showfliers=False,\n",
#     805     "                width=0.15, boxprops={'zorder': 3, 'facecolor': 'none'}, ax=ax)\n",
#     806     "\n",
#     807     "        # Makeup\n",
#     808     "        ax.set_title('Parameter: ' + param, fontsize=18)\n",
#     809     "        ax.set_xlabel('Best fit parameter value', fontsize=16)\n",
#     810     "\n",
#     811     "    plt.show()"
#     812    ]
#     813   },
#     814   {
#     815    "cell_type": "code",
#     816    "execution_count": 1,
#     817    "id": "7e77d5f4-126c-4f04-91da-01acfc5de472",
#     818    "metadata": {},
#     819    "outputs": [],
#     820    "source": [
#     821     "def fig_modelpred_on_behav(ev_per_trial, p_hit_per_trial, all_users_folder):\n",
#     822     "\n",
#     823     "    # Timepoints\n",
#     824     "    window_size = 16\n",
#     825     "    N_trials = 112\n",
#     826     "    timepoints = ['t'+ str(t+1) for t in range(int(N_trials/window_size))]\n",
#     827     "\n",
#     828     "    # Load behaviour and compute stats\n",
#     829     "    hit_perc_per_t = pd.read_pickle(all_users_folder + 'hit_perc_per_t/hit_perc_per_t_w' + str(window_size) + '.pkl');\n",
#     830     "    hit_perc_per_t.drop('ID', axis=1, inplace=True);\n",
#     831     "    stats_hits_perc_per_t = hit_perc_per_t.groupby('Code').agg(['mean', 'var']).T.swaplevel(axis=0);\n",
#     832     "\n",
#     833     "    # Load model predictions and compute stats\n",
#     834     "    ev_per_trial.drop('ID', axis=1, inplace=True);\n",
#     835     "    stats_ev_per_trial = ev_per_trial.groupby('Cue').agg(['mean', 'var']).T.swaplevel(axis=0)\n",
#     836     "    stats_ev_per_trial.columns = 'Cue_'+stats_ev_per_trial.columns\n",
#     837     "\n",
#     838     "    p_hit_per_trial.drop('ID', axis=1, inplace=True);\n",
#     839     "    stats_p_hit_per_trial = p_hit_per_trial.groupby('Cue').agg(['mean', 'var']).T.swaplevel(axis=0)\n",
#     840     "    stats_p_hit_per_trial.columns = 'Cue_'+stats_p_hit_per_trial.columns\n",
#     841     "\n",
#     842     "    # Plot\n",
#     843     "    f, axs = plt.subplots(2, 1, figsize=(10, 6), dpi=80)\n",
#     844     "    plt.subplots_adjust(hspace = 0.4)\n",
#     845     "\n",
#     846     "    x_mod = np.arange(len(stats_ev_per_trial.loc['mean']))+1\n",
#     847     "    x_behav = np.arange(len(timepoints))*4+4\n",
#     848     "\n",
#     849     "    for cue, color, alpha in zip(['Cue_HP', 'Cue_LP', 'Cue_LR', 'Cue_HR'], ['red', 'red', 'green', 'green'], [0.6, 0.3, 0.3, 0.6]):\n",
#     850     "        # Hit probabilites\n",
#     851     "        m=axs[0].plot(x_mod, stats_p_hit_per_trial.loc['mean'][cue], '.-', color=color, alpha=alpha);\n",
#     852     "        # Behaviour: sliding average\n",
#     853     "        b=axs[0].plot(x_behav, stats_hits_perc_per_t.loc['mean'][cue], '.-', color='gray', alpha=alpha);\n",
#     854     "        # Expected values\n",
#     855     "        m=axs[1].plot(x_mod, stats_ev_per_trial.loc['mean'][cue], '.-', color=color, alpha=alpha);\n",
#     856     "\n",
#     857     "    for ax in axs:\n",
#     858     "        ax.grid(axis='x', color='0.95');\n",
#     859     "        ax.set_xticks(x_mod);\n",
#     860     "    \n",
#     861     "    axs[0].set_title('Model probability of hit', fontsize=16);\n",
#     862     "    axs[1].set_title('Model expected values', fontsize=16);\n",
#     863     "    \n",
#     864     "    axs[0].set_ylabel(\"Hit [%]\", fontsize=16);\n",
#     865     "    axs[1].set_ylabel(\"Values\", fontsize=16);\n",
#     866     "    \n",
#     867     "    axs[0].set_ylim([0,1]);\n",
#     868     "    axs[1].set_ylim([-3,3]);\n",
#     869     "    \n",
#     870     "    axs[0].legend(b, {'Behaviour'})\n",
#     871     "    \n",
#     872     "    plt.show()"
#     873    ]
#     874   },
#     875   {
#     876    "cell_type": "code",
#     877    "execution_count": null,
#     878    "id": "dd08ec75-c910-4087-a9df-dd3d6ad6dd83",
#     879    "metadata": {},
#     880    "outputs": [],
#     881    "source": []
#     882   }
#     883  ],
#     884  "metadata": {
#     885   "kernelspec": {
#     886    "display_name": "Python 3 (ipykernel)",
#     887    "language": "python",
#     888    "name": "python3"
#     889   },
#     890   "language_info": {
#     891    "codemirror_mode": {
#     892     "name": "ipython",
#     893     "version": 3
#     894    },
#     895    "file_extension": ".py",
#     896    "mimetype": "text/x-python",
#     897    "name": "python",
#     898    "nbconvert_exporter": "python",
#     899    "pygments_lexer": "ipython3",
#     900    "version": "3.8.12"
#     901   }
#     902  },
#     903  "nbformat": 4,
#     904  "nbformat_minor": 5
#     905 }
#
# File ~/opt/anaconda3/envs/python38/lib/python3.8/site-packages/scipy/optimize/_minimize.py:672, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     669     res = _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     670                                **options)
#     671 elif meth == 'powell':
# --> 672     res = _minimize_powell(fun, x0, args, callback, bounds, **options)
#     673 elif meth == 'cg':
#     674     res = _minimize_cg(fun, x0, args, jac, callback, **options)
#
# File ~/opt/anaconda3/envs/python38/lib/python3.8/site-packages/scipy/optimize/_optimize.py:3183, in _minimize_powell(func, x0, args, callback, bounds, xtol, ftol, maxiter, maxfev, disp, direc, return_all, **unknown_options)
#    3179     if np.any(lower_bound > x0) or np.any(x0 > upper_bound):
#    3180         warnings.warn("Initial guess is not within the specified bounds",
#    3181                       OptimizeWarning, 3)
# -> 3183 fval = squeeze(func(x))
#    3184 x1 = x.copy()
#    3185 iter = 0
#
# File ~/opt/anaconda3/envs/python38/lib/python3.8/site-packages/scipy/optimize/_optimize.py:496, in _wrap_scalar_function_maxfun_validation.<locals>.function_wrapper(x, *wrapper_args)
#     494 ncalls[0] += 1
#     495 # A copy of x is sent to the user function (gh13740)
# --> 496 fx = function(np.copy(x), *(wrapper_args + args))
#     497 # Ideally, we'd like to a have a true scalar returned from f(x). For
#     498 # backwards-compatibility, also allow np.array([1.3]),
#     499 # np.array([[1.3]]) etc.
#     500 if not np.isscalar(fx):
#
# File /Volumes/GoogleDrive/Mon Drive/PAT/data_analysis/functions.ipynb:518, in compute_nLL(self, param_values)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "id": "83916d5c-847d-4008-b2a0-cf1a24e8ab3b",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "import numpy as np\n",
#      11     "import pandas as pd\n",
#      12     "import matplotlib.pyplot as plt\n",
#      13     "from scipy.optimize import minimize\n",
#      14     "import seaborn as sns\n",
#      15     "import ptitprince as pt # rainplot\n",
#      16     "import scipy"
#      17    ]
#      18   },
#      19   {
#      20    "cell_type": "markdown",
#      21    "id": "aec45ccb-f5c6-45bf-bdf9-627bd1e9c037",
#      22    "metadata": {},
#      23    "source": [
#      24     "# Data cleaning"
#      25    ]
#      26   },
#      27   {
#      28    "cell_type": "code",
#      29    "execution_count": 2,
#      30    "id": "ceb57213-a7a8-408d-906a-9fd6def7846e",
#      31    "metadata": {},
#      32    "outputs": [],
#      33    "source": [
#      34     "def extract_hits_fbs(df):\n",
#      35     "    \n",
#      36     "    isHit_all_cues = {}\n",
#      37     "    fbs_all_cues = {}\n",
#      38     "    trialNo_all_cues = {}\n",
#      39     "        \n",
#      40     "    for cue in ['HR', 'LR', 'HP', 'LP']:\n",
#      41     "\n",
#      42     "        # Extract cue data\n",
#      43     "        cue_data_tmp = df[df['Code']==('Cue_' + cue)] \n",
#      44     "\n",
#      45     "        # Create a cue trial column\n",
#      46     "        cue_data_tmp.insert(0, \"CueTrial\", list(range(1,len(cue_data_tmp)+1)))\n",
#      47     "\n",
#      48     "        # Store all in dictionnaries\n",
#      49     "        isHit_all_cues[cue]=cue_data_tmp['isHit'].tolist()\n",
#      50     "        fbs_all_cues[cue]=cue_data_tmp['FBs'].tolist()\n",
#      51     "        trialNo_all_cues[cue]=cue_data_tmp['Trial'].tolist()\n",
#      52     "        \n",
#      53     "    return isHit_all_cues, fbs_all_cues, trialNo_all_cues"
#      54    ]
#      55   },
#      56   {
#      57    "cell_type": "markdown",
#      58    "id": "ddc33407-ae4b-4877-b8bb-8efeacf9965c",
#      59    "metadata": {},
#      60    "source": [
#      61     "# Value functions"
#      62    ]
#      63   },
#      64   {
#      65    "cell_type": "code",
#      66    "execution_count": 3,
#      67    "id": "ce8732e2-395b-4f14-8616-a761b6d7c624",
#      68    "metadata": {},
#      69    "outputs": [],
#      70    "source": [
#      71     "def rescorla_wagner_2LR_FB_weightRew(fbs_all_cues, trialNo_all_cues, param_values, param_names):\n",
#      72     "    \n",
#      73     "    # Free parameters\n",
#      74     "    v0 = param_values[param_names.index('v0')]\n",
#      75     "    w = param_values[param_names.index('w')]\n",
#      76     "    alpha_pos = param_values[param_names.index('alpha_rew')]\n",
#      77     "    alpha_neg = param_values[param_names.index('alpha_pun')]\n",
#      78     "    \n",
#      79     "    # Initialise empty dicitonnary\n",
#      80     "    vt_all_cues = dict.fromkeys(fbs_all_cues.keys())\n",
#      81     "    \n",
#      82     "    # Iterate over cues\n",
#      83     "    for cue, fbs in fbs_all_cues.items():\n",
#      84     "        \n",
#      85     "        # Initialise vector of values\n",
#      86     "        vt = np.empty(len(fbs))\n",
#      87     "        vt.fill(np.nan)\n",
#      88     "        \n",
#      89     "        # Fill in prior\n",
#      90     "        # If want specific prior per cue, check value of cue\n",
#      91     "        vt[0] = v0\n",
#      92     "        \n",
#      93     "        # Iterate to fill in vector\n",
#      94     "        for t in range(1,len(vt)):\n",
#      95     "            \n",
#      96     "           # scale fb\n",
#      97     "            if abs(fbs[t-1]) == 5: \n",
#      98     "                fbs[t-1] = w * fbs[t-1] \n",
#      99     "                \n",
#     100     "            # Compute prediction error\n",
#     101     "            pe = fbs[t-1] - vt[t-1]\n",
#     102     "                        \n",
#     103     "            # Compute new vt and fill in \n",
#     104     "            if fbs[t-1] > 0:\n",
#     105     "                vt[t] = vt[t-1] + alpha_rew * pe\n",
#     106     "            elif fbs[t-1] < 0:\n",
#     107     "                vt[t] = vt[t-1] + alpha_pun * pe\n",
#     108     "            else:\n",
#     109     "                print('error, fb either 0 or nan?')\n",
#     110     "        \n",
#     111     "        vt_all_cues[cue] = vt\n",
#     112     "    \n",
#     113     "    return vt_all_cues"
#     114    ]
#     115   },
#     116   {
#     117    "cell_type": "code",
#     118    "execution_count": 4,
#     119    "id": "42013a82-1712-425b-aa48-f14ca98bd5b8",
#     120    "metadata": {},
#     121    "outputs": [],
#     122    "source": [
#     123     "def rescorla_wagner_2LR_FB(fbs_all_cues, trialNo_all_cues, param_values, param_names):\n",
#     124     "    \n",
#     125     "    # Free parameters\n",
#     126     "    v0 = param_values[param_names.index('v0')]\n",
#     127     "    alpha_rew = param_values[param_names.index('alpha_rew')]\n",
#     128     "    alpha_pun = param_values[param_names.index('alpha_pun')]\n",
#     129     "    \n",
#     130     "    # Initialise empty dicitonnary\n",
#     131     "    vt_all_cues = dict.fromkeys(fbs_all_cues.keys())\n",
#     132     "    \n",
#     133     "    # Iterate over cues\n",
#     134     "    for cue, fbs in fbs_all_cues.items():\n",
#     135     "        \n",
#     136     "        # Initialise vector of values\n",
#     137     "        vt = np.empty(len(fbs))\n",
#     138     "        vt.fill(np.nan)\n",
#     139     "        \n",
#     140     "        # Fill in prior\n",
#     141     "        # If want specific prior per cue, check value of cue\n",
#     142     "        vt[0] = v0\n",
#     143     "        \n",
#     144     "        # Iterate to fill in vector\n",
#     145     "        for t in range(1,len(vt)):\n",
#     146     "            \n",
# ...
#     579     "        nLLs_all_cues = dict.fromkeys(p_hit_all_cues.keys())\n",
#     580     "        total_nLL_all_cues = dict.fromkeys(p_hit_all_cues.keys())\n",
#     581     "        Ntrials_per_cue = dict.fromkeys(p_hit_all_cues.keys())\n",
#     582     "        \n",
#     583     "        # Iterate over cues\n",
#     584     "        for cue, p_hit in p_hit_all_cues.items():\n",
#     585     "            isHit = isHit_all_cues[cue]\n",
#     586     "            # compute likelihoods of choices\n",
#     587     "            ll_choice = []\n",
#     588     "            almost_zero = np.finfo(float).tiny\n",
#     589     "            for ind, hit in enumerate(isHit):\n",
#     590     "                if hit==1:\n",
#     591     "                    p_ =  p_hit[ind]\n",
#     592     "                else:\n",
#     593     "                    p_ =  1-p_hit[ind]\n",
#     594     "                    \n",
#     595     "                ll_choice.append(almost_zero if p_<almost_zero else p_)\n",
#     596     "                             \n",
#     597     "            nLLs = -np.log(ll_choice)\n",
#     598     "            nLLs_all_cues[cue] = nLLs\n",
#     599     "            total_nLL_all_cues[cue] = sum(nLLs)\n",
#     600     "            Ntrials_per_cue[cue] = len(nLLs)\n",
#     601     "            \n",
#     602     "        return total_nLL_all_cues, nLLs_all_cues, Ntrials_per_cue\n",
#     603     "    \n",
#     604     "    def fit(self, param_lower_bound, param_upper_bound, n_iterations, method='Powell'):\n",
#     605     "        \n",
#     606     "        # compute sequence of parameter bounds\n",
#     607     "        bounds = []\n",
#     608     "        for low, up in zip(param_lower_bound,param_upper_bound):\n",
#     609     "            bounds.append([low,up])\n",
#     610     "        \n",
#     611     "        # init\n",
#     612     "        mat_min_nLL=[]\n",
#     613     "        mat_best_params=[]\n",
#     614     "\n",
#     615     "        for i in range(0,n_iterations):\n",
#     616     "\n",
#     617     "            # define the starting point as a random sample from the domain\n",
#     618     "            initial_guess = np.array(param_lower_bound) + np.random.rand(len(param_lower_bound)) * (np.array(param_upper_bound) - np.array(param_lower_bound))\n",
#     619     "\n",
#     620     "            # find the min likelihood \n",
#     621     "            result = minimize(self.compute_nLL, initial_guess, method = method, bounds = bounds, \n",
#     622     "                              options={'xtol': 1e-8, 'disp': False})\n",
#     623     "\n",
#     624     "            # store min_nLL and parameters\n",
#     625     "            mat_min_nLL.append(result.fun)\n",
#     626     "            mat_best_params.append(result.x)\n",
#     627     "\n",
#     628     "        # Find best params\n",
#     629     "        ind = np.argmin(mat_min_nLL)\n",
#     630     "        best_params = mat_best_params[ind]\n",
#     631     "\n",
#     632     "        # Compute best LL and store in mod1\n",
#     633     "        nLL = self.compute_nLL(best_params)   \n",
#     634     "                \n",
#     635     "    \n",
#     636     "    def compute_nLL(self, param_values):\n",
#     637     "        \n",
#     638     "        fbs_all_cues = self.fbs_all_cues\n",
#     639     "        isHit_all_cues = self.isHit_all_cues\n",
#     640     "        trialNo_all_cues = self.trialNo_all_cues\n",
#     641     "        \n",
#     642     "        # set parameter values\n",
#     643     "        self.set_param_values(param_values)\n",
#     644     "\n",
#     645     "        # compute expected values\n",
#     646     "        vt_all_cues = self.value_fct(fbs_all_cues, self.trialNo_all_cues, self.param_values, self.param_names)\n",
#     647     "        \n",
#     648     "        # compute hit probability\n",
#     649     "        p_hit_all_cues  = self.dec_fct(vt_all_cues, self.param_values, self.param_names)\n",
#     650     "        \n",
#     651     "        # compute nLL per cue\n",
#     652     "        total_nLL_all_cues, nLLs_all_cues, Ntrials_per_cue = self.compute_ll_per_cue(p_hit_all_cues, isHit_all_cues)\n",
#     653     "        \n",
#     654     "        # compute total neg LL (sum over cues, i.e. multiply likelihoods)\n",
#     655     "        nLL = sum(total_nLL_all_cues.values())\n",
#     656     "        \n",
#     657     "        # save total number of trials\n",
#     658     "        Ntrials = sum(Ntrials_per_cue.values())\n",
#     659     "        \n",
#     660     "        # Set values\n",
#     661     "        self.v = vt_all_cues\n",
#     662     "        self.p_hit = p_hit_all_cues\n",
#     663     "        self.cue_nLLs = nLLs_all_cues\n",
#     664     "        self.total_cue_nLL = total_nLL_all_cues\n",
#     665     "        self.nLL = nLL\n",
#     666     "        self.Ntrials = Ntrials\n",
#     667     "        \n",
#     668     "        return nLL"
#     669    ]
#     670   },
#     671   {
#     672    "cell_type": "markdown",
#     673    "id": "3878fb07-a01b-475a-92cb-f4186e5b7c67",
#     674    "metadata": {},
#     675    "source": [
#     676     "# Ploting"
#     677    ]
#     678   },
#     679   {
#     680    "cell_type": "code",
#     681    "execution_count": 28,
#     682    "id": "f36fce68-ee9e-4a05-9bfe-b6377fc8b4d8",
#     683    "metadata": {},
#     684    "outputs": [],
#     685    "source": [
#     686     "def plot_model_behaviour_allcues(mod1, window_size, save_fig=False):\n",
#     687     "    \n",
#     688     "    # User folder for running average data\n",
#     689     "    user_folder = 'data/user_' + mod1.ID + '/cue_hit_miss_perc/'\n",
#     690     "    \n",
#     691     "    # Timepoints\n",
#     692     "    N_trials = 28\n",
#     693     "    N_iter = int(N_trials/window_size)\n",
#     694     "    timepoints = ['t'+ str(t+1) for t in range(N_iter)]\n",
#     695     "    xt = (np.arange(len(timepoints))+1)*window_size\n",
#     696     "\n",
#     697     "    fig, axs = plt.subplots(4, 1, figsize=(10,10), facecolor='white')\n",
#     698     "    plt.subplots_adjust(hspace=0.5)\n",
#     699     "\n",
#     700     "    cues = ['HR', 'HP', 'LR', 'LP']\n",
#     701     "\n",
#     702     "    for i,cue in enumerate(cues):\n",
#     703     "\n",
#     704     "        ax = axs[i]\n",
#     705     "\n",
#     706     "        # Extract data for plotting\n",
#     707     "        p_hit_model = mod1.p_hit[cue]\n",
#     708     "        vt_model = mod1.v[cue]\n",
#     709     "        isHit = mod1.isHit_all_cues[cue]\n",
#     710     "        fbs = mod1.fbs_all_cues[cue]\n",
#     711     "        hit_miss_perc = pd.read_pickle(user_folder + 'hit_miss_perc_' + cue + '_window_size_' + str(window_size) + '.pkl')\n",
#     712     "\n",
#     713     "        # Plot fbs\n",
#     714     "        height_fb = 1.13\n",
#     715     "        x = [ind+1 for ind, el in enumerate(fbs) if el == 5]\n",
#     716     "        l_fb_5 = ax.scatter(x, height_fb * np.ones(len(x)), c='green', alpha=0.9)\n",
#     717     "        x = [ind+1 for ind, el in enumerate(fbs) if el == 1]\n",
#     718     "        l_fb_1 = ax.scatter(x, height_fb * np.ones(len(x)), c='green', alpha=0.1)\n",
#     719     "        x = [ind+1 for ind, el in enumerate(fbs) if el == -1]\n",
#     720     "        l_fb_m1 = ax.scatter(x, height_fb * np.ones(len(x)), c='red', alpha=0.1)\n",
#     721     "        x = [ind+1 for ind, el in enumerate(fbs) if el == -5]\n",
#     722     "        l_fb_m5 = ax.scatter(x, height_fb * np.ones(len(x)), c='red', alpha=0.9)\n",
#     723     "\n",
#     724     "        # Plot hits (marker)\n",
#     725     "        height_hit = 1.2\n",
#     726     "        x_hit = [ind+1 for ind, el in enumerate(isHit) if el == 1]\n",
#     727     "        l_hits = ax.scatter(x_hit, height_hit * np.ones(len(x_hit)), c='black', alpha=1, marker='v')\n",
#     728     "\n",
#     729     "        # Plot hit perc (running average)\n",
#     730     "        l_wind_m, = ax.plot(xt, hit_miss_perc.loc['hit'], '.-', color='darkorange', alpha=1)\n",
#     731     "\n",
#     732     "        # Plot probability of hits (from model)\n",
#     733     "        l_p_h_mod, = ax.plot(list(range(1,len(p_hit_model)+1)), p_hit_model)\n",
#     734     "\n",
#     735     "        # Legend\n",
#     736     "        ax.legend([l_wind_m, l_p_h_mod], \n",
#     737     "                  ['Hit running average', \n",
#     738     "                   'Hit model probability (alpha=' + str(round(mod1.param_values[1],2))+\n",
#     739     "                   ', v0='+ str(round(mod1.param_values[0],2))+\n",
#     740     "                   ', beta='+ str(round(mod1.param_values[2],2)) + ')'],\n",
#     741     "                  frameon=False)\n",
#     742     "\n",
#     743     "        # Labels etc \n",
#     744     "        ax.set_ylim([0,1.24])\n",
#     745     "\n",
#     746     "        # Title \n",
#     747     "        ax.set_title(cue)\n",
#     748     "\n",
#     749     "        # Plot vertical grid\n",
#     750     "        ax.grid(axis=\"x\", alpha=0.1)\n",
#     751     "\n",
#     752     "        # Plot horizontal line at 0\n",
#     753     "        ax.plot(np.arange(-1,30), np.zeros(len(np.arange(-1,30))), 'k--', alpha=0.5, linewidth=1.0)\n",
#     754     "\n",
#     755     "        # x-axis (trials)\n",
#     756     "        x_ticks = list(range(1,len(fbs)+1))\n",
#     757     "        ax.set_xlim(x_ticks[0]-1,x_ticks[-1]+1)\n",
#     758     "        ax.set_xticks(x_ticks)\n",
#     759     "        ax.set_xlabel('', fontsize = 18)\n",
#     760     "\n",
#     761     "    \n",
#     762     "    if save_fig:\n",
#     763     "        user_fig = 'data/user_' + mod1.ID + '/behav_' + mod1.mod_name + '.png'\n",
#     764     "        plt.savefig(user_fig)\n",
#     765     "        plt.close() \n",
#     766     "    else:\n",
#     767     "        plt.show()"
#     768    ]
#     769   },
#     770   {
#     771    "cell_type": "code",
#     772    "execution_count": 11,
#     773    "id": "35358520-9aa4-4336-bf96-a7c32c92454b",
#     774    "metadata": {},
#     775    "outputs": [],
#     776    "source": [
#     777     "def plot_model_parameters(data_mod, param_names):\n",
#     778     "    \n",
#     779     "    Nparam = len(param_names)\n",
#     780     "    \n",
#     781     "    if Nparam<=3:\n",
#     782     "        f, axs = plt.subplots(1, Nparam, figsize=(Nparam*6, 5))\n",
#     783     "    elif Nparam==4:\n",
#     784     "        f, axs = plt.subplots(2, 2, figsize=(2*6, 2*5))\n",
#     785     "        axs = axs.reshape(-1)\n",
#     786     "    else:\n",
#     787     "        f, axs = plt.subplots(2, 3, figsize=(3*6, 2*5))\n",
#     788     "        axs = axs.reshape(-1)\n",
#     789     "        \n",
#     790     "    plt.subplots_adjust(hspace = 0.3)\n",
#     791     "        \n",
#     792     "    pal = sns.color_palette(n_colors=1)\n",
#     793     "\n",
#     794     "    for ax, param in zip(axs, param_names):\n",
#     795     "\n",
#     796     "        y = data_mod[param].tolist()\n",
#     797     "\n",
#     798     "        # plot clouds\n",
#     799     "        pt.half_violinplot(ax=ax, x = y, palette = pal, bw = .2, cut = 0., scale = \"area\", width = .6, inner = None, orient = 'h')\n",
#     800     "\n",
#     801     "        # add rain\n",
#     802     "        sns.stripplot(ax=ax, x = y, palette = pal, edgecolor = \"white\", size = 5, jitter = 1, zorder = 0, orient = 'h', alpha=.35)\n",
#     803     "\n",
#     804     "        sns.boxplot(x = y, saturation=1, showfliers=False,\n",
#     805     "                width=0.15, boxprops={'zorder': 3, 'facecolor': 'none'}, ax=ax)\n",
#     806     "\n",
#     807     "        # Makeup\n",
#     808     "        ax.set_title('Parameter: ' + param, fontsize=18)\n",
#     809     "        ax.set_xlabel('Best fit parameter value', fontsize=16)\n",
#     810     "\n",
#     811     "    plt.show()"
#     812    ]
#     813   },
#     814   {
#     815    "cell_type": "code",
#     816    "execution_count": 1,
#     817    "id": "7e77d5f4-126c-4f04-91da-01acfc5de472",
#     818    "metadata": {},
#     819    "outputs": [],
#     820    "source": [
#     821     "def fig_modelpred_on_behav(ev_per_trial, p_hit_per_trial, all_users_folder):\n",
#     822     "\n",
#     823     "    # Timepoints\n",
#     824     "    window_size = 16\n",
#     825     "    N_trials = 112\n",
#     826     "    timepoints = ['t'+ str(t+1) for t in range(int(N_trials/window_size))]\n",
#     827     "\n",
#     828     "    # Load behaviour and compute stats\n",
#     829     "    hit_perc_per_t = pd.read_pickle(all_users_folder + 'hit_perc_per_t/hit_perc_per_t_w' + str(window_size) + '.pkl');\n",
#     830     "    hit_perc_per_t.drop('ID', axis=1, inplace=True);\n",
#     831     "    stats_hits_perc_per_t = hit_perc_per_t.groupby('Code').agg(['mean', 'var']).T.swaplevel(axis=0);\n",
#     832     "\n",
#     833     "    # Load model predictions and compute stats\n",
#     834     "    ev_per_trial.drop('ID', axis=1, inplace=True);\n",
#     835     "    stats_ev_per_trial = ev_per_trial.groupby('Cue').agg(['mean', 'var']).T.swaplevel(axis=0)\n",
#     836     "    stats_ev_per_trial.columns = 'Cue_'+stats_ev_per_trial.columns\n",
#     837     "\n",
#     838     "    p_hit_per_trial.drop('ID', axis=1, inplace=True);\n",
#     839     "    stats_p_hit_per_trial = p_hit_per_trial.groupby('Cue').agg(['mean', 'var']).T.swaplevel(axis=0)\n",
#     840     "    stats_p_hit_per_trial.columns = 'Cue_'+stats_p_hit_per_trial.columns\n",
#     841     "\n",
#     842     "    # Plot\n",
#     843     "    f, axs = plt.subplots(2, 1, figsize=(10, 6), dpi=80)\n",
#     844     "    plt.subplots_adjust(hspace = 0.4)\n",
#     845     "\n",
#     846     "    x_mod = np.arange(len(stats_ev_per_trial.loc['mean']))+1\n",
#     847     "    x_behav = np.arange(len(timepoints))*4+4\n",
#     848     "\n",
#     849     "    for cue, color, alpha in zip(['Cue_HP', 'Cue_LP', 'Cue_LR', 'Cue_HR'], ['red', 'red', 'green', 'green'], [0.6, 0.3, 0.3, 0.6]):\n",
#     850     "        # Hit probabilites\n",
#     851     "        m=axs[0].plot(x_mod, stats_p_hit_per_trial.loc['mean'][cue], '.-', color=color, alpha=alpha);\n",
#     852     "        # Behaviour: sliding average\n",
#     853     "        b=axs[0].plot(x_behav, stats_hits_perc_per_t.loc['mean'][cue], '.-', color='gray', alpha=alpha);\n",
#     854     "        # Expected values\n",
#     855     "        m=axs[1].plot(x_mod, stats_ev_per_trial.loc['mean'][cue], '.-', color=color, alpha=alpha);\n",
#     856     "\n",
#     857     "    for ax in axs:\n",
#     858     "        ax.grid(axis='x', color='0.95');\n",
#     859     "        ax.set_xticks(x_mod);\n",
#     860     "    \n",
#     861     "    axs[0].set_title('Model probability of hit', fontsize=16);\n",
#     862     "    axs[1].set_title('Model expected values', fontsize=16);\n",
#     863     "    \n",
#     864     "    axs[0].set_ylabel(\"Hit [%]\", fontsize=16);\n",
#     865     "    axs[1].set_ylabel(\"Values\", fontsize=16);\n",
#     866     "    \n",
#     867     "    axs[0].set_ylim([0,1]);\n",
#     868     "    axs[1].set_ylim([-3,3]);\n",
#     869     "    \n",
#     870     "    axs[0].legend(b, {'Behaviour'})\n",
#     871     "    \n",
#     872     "    plt.show()"
#     873    ]
#     874   },
#     875   {
#     876    "cell_type": "code",
#     877    "execution_count": null,
#     878    "id": "dd08ec75-c910-4087-a9df-dd3d6ad6dd83",
#     879    "metadata": {},
#     880    "outputs": [],
#     881    "source": []
#     882   }
#     883  ],
#     884  "metadata": {
#     885   "kernelspec": {
#     886    "display_name": "Python 3 (ipykernel)",
#     887    "language": "python",
#     888    "name": "python3"
#     889   },
#     890   "language_info": {
#     891    "codemirror_mode": {
#     892     "name": "ipython",
#     893     "version": 3
#     894    },
#     895    "file_extension": ".py",
#     896    "mimetype": "text/x-python",
#     897    "name": "python",
#     898    "nbconvert_exporter": "python",
#     899    "pygments_lexer": "ipython3",
#     900    "version": "3.8.12"
#     901   }
#     902  },
#     903  "nbformat": 4,
#     904  "nbformat_minor": 5
#     905 }
#
# NameError: name 'alpha_rew' is not defined
